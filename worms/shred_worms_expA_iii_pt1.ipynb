# %% [markdown]
# # Experiment A iii: Sensitivity Analysis part 1 - Effect of Variance

# %% [markdown]
# Data obtained from Global Brain Dynamics Embed the Motor Command Sequence of Caenorhabditis elegans. Cell, 163(3), 656–669. http://doi.org/10.1016/j.cell.2015.09.034

# %% [markdown]
# SHRED (SHallow REcurrent Decoder) models are a network architecture that merges a recurrent layer (LSTM) with a shallow decoder network (SDN) to reconstruct high-dimensional spatio-temporal fields from a trajectory of sensor measurements of the field. More formally, the SHRED architecture can be written as
# $$ \mathcal {H} \left( \{ y_i \} _{i=t-k}^t \right) = \mathcal {F} \left( \mathcal {G} \left( \{ y_i \} _{i=t-k}^t \right) ; W_{RN}) ; W_{SD} \right)$$
# where $\mathcal F$ is a feed forward network parameterized by weights $W_{SD}$, $\mathcal G$ is a LSTM network parameterized by weights $W_{RN}$, and $\{ y_i \} _{i=t-k}^t$ is a trajectory of sensor measurements of a high-dimensional spatio-temporal field $\{ x_i \} _{i=t-k}^t$.

# %% [markdown]
# **Experiment 1.1: Effect of neuron activity variance on SHRED performance.**
# - group neurons into two categories: high variance, low variance
# - randomly pick 3 from group with high variance
# - randomly pick 3 from group with low variance
# - randomly pick 3 from entire set of neurons

# %%
# Importing all dependencies 
import numpy as np
import numpy as np
import torch
import subprocess
import os
import torch
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import random
import mne
from scipy.signal import butter, filtfilt
from scipy.signal import welch
from scipy.interpolate import CubicSpline
from scipy.io import loadmat
from sklearn.linear_model import Ridge

# %%
#Importing packages
HOME_DIR = "/Users/amyrude/Downloads/Kutz_Research/SHRED_neuro/neuralSHRED"

SHRED_DIR = os.path.join(HOME_DIR, "sindy-shred-main")
import sys 
sys.path.append(SHRED_DIR)

from processdata import load_data
from processdata import TimeSeriesDataset
import sindy
import pysindy as ps
from pysindy.differentiation import FiniteDifference

os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# /Users/amyrude/Downloads/Kutz_Research/SHRED_neuro/shredneuro/lib/python3.13/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound

# %% [markdown]
# # Data Format
# - 5 worms
# - 18 mins at roughly 2.85 samples per second --> ~3000 samples per trial
# - 107 - 131 neurons

# %% [markdown]
# *Worm One, No Stim*

# %%
# Loading the Dataset
os.chdir("../")

data_path = os.path.join(HOME_DIR, 'worms/data/WT_NoStim.mat')
data = loadmat(data_path)
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'WT_NoStim', 'WT_Stim'])

# %%
# Working with the no stim condition -- WORM ONE
no_stim = data['WT_NoStim']
neuron_data = no_stim[0][0][0] #3137 timepoints, 109 neurons 

time = no_stim[0][0][4]
dt = time[1][0] - time[0][0]

m = neuron_data.shape[0] # number of timepoints
n = neuron_data.shape[1] #number of neurons 

neuron_data_cor = no_stim[0][0][1]

neuron_name = []
for i in range((n-1)):
    neuron_name.append(no_stim[0][0][3][0][i][0])

sr = no_stim[0][0][6]
# Movement Classifications;  
# ‘FWD’ forward crawling ‘SLOW’ forward slowing ‘DT’ dorsal post reversal turn ‘VT’ ventral post reversal turn 
# ‘REV1’ reverse crawling ‘REV2’ reverse crawling ‘REVSUS’ sustained reverse crawling ‘NOSTATE’ - ambiguous
FWD = no_stim[0][0][7][0][0][0]
SLOW = no_stim[0][0][7][0][0][1]
DT = no_stim[0][0][7][0][0][2]
VT = no_stim[0][0][7][0][0][3]
REV1 = no_stim[0][0][7][0][0][4]
REV2 = no_stim[0][0][7][0][0][5]
REVSUS = no_stim[0][0][7][0][0][6]
NOSTATE = no_stim[0][0][7][0][0][7]

print('number timepoints(m)', m, 'number neurons(n):', n)
print('dt', dt)
print('sr', sr, 'Hz')
# Out:
# number timepoints(m) 3137 number neurons(n): 109
# dt 0.34427797258527254
# sr [[2.90462963]] Hz

# %%
load_X = neuron_data_cor

plt.plot(time, load_X)
plt.xlabel('Time (s)', fontsize = 15)
plt.ylabel('Neural Activity', fontsize = 15)
plt.title('[0,T]',  fontsize = 20)
plt.show()

# %% [markdown]
# Preparing the data (use only first half)

# %%
load_X = load_X[:int(m/2),:]
time = time[:int(m/2)].flatten()
print(load_X.shape)

plt.plot(time, load_X)
plt.xlabel('Time (s)', fontsize = 15)
plt.ylabel('Neural Activity', fontsize = 15)
plt.title('[0,T/2]', fontsize = 20)
plt.show()
print(time[-1])
# Out:
# (1568, 109)
# 539.4835830411221

# %% [markdown]
# Studying the variance of the neuronal activity

# %% [markdown]
# ## Running the Experiments - High vs low variance reconstructions

# %%
latent_dim = 32
poly_order = 1
include_sine = False
library_dim = sindy.library_size(latent_dim, poly_order, include_sine, True)
import sindy_shred
num_neurons = 3 
lags = 100
new_m = int(m/2)
test_val_size = int(0.2*m) 
print(test_val_size)
train_indices = np.arange(0, new_m - lags - test_val_size)
mask = np.ones(new_m - lags)
mask[train_indices] = 0
valid_test_indices = np.arange(0, new_m - lags)[np.where(mask!=0)[0]]
valid_indices = valid_test_indices[:int(test_val_size/2)]
test_indices = valid_test_indices[int(test_val_size/2):test_val_size]

##### Study the variance of the neurons
# Splitting into high and low variance groups
var = np.std(load_X[train_indices], axis = 0)
var_ave = np.mean(var)
print(var_ave)
neuron_index = np.arange(var.shape[0])

#plotting the distribution of std 
plt.figure(figsize = (4,2.5))
plt.axhspan(0, var_ave, color='darkblue', alpha=0.3)
plt.axhspan(var_ave,0.62 ,color='red', alpha=0.3)
plt.scatter(neuron_index, var, color = 'black', label = '$\sigma$')
plt.axhline(var_ave, color = 'red', linewidth = 2)
plt.xlabel('Neuron', fontsize = 14)
plt.ylabel('$\sigma$', fontsize = 16)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

plt.ylim((0,0.62))
plt.tight_layout()
plt.savefig(os.path.join(HOME_DIR, f'worms/data_output/figs/std_scatter.png'), transparent=True, dpi=500)
plt.show()


# Finding indices for high variance cases
high_ind = np.where(var > var_ave)[0]
low_ind = np.where(var < var_ave)[0]
plt.figure(figsize = (4,2.5))

plt.plot(time[train_indices], load_X[train_indices][:,high_ind], color = 'red', alpha = 0.4)
plt.plot(time[train_indices], load_X[train_indices][:,low_ind], color = 'darkblue', alpha = 0.4)
print('number high variance neurons', high_ind.shape[0])
print('number low variance neurons', low_ind.shape[0])
plt.xlabel('Time(s)', fontsize = 14)
plt.ylabel('Neuron Activity', fontsize = 14)
plt.tight_layout()
plt.savefig(os.path.join(HOME_DIR, f'worms/data_output/figs/var_traces.png'), transparent=True, dpi=500)
plt.show()



# ## high variance
# for k in range(21,25):
#     # Randomly select the neurons to train the SHRED model on
#     indices = np.random.choice(high_ind.shape[0], size= num_neurons, replace=False) 
#     neuron_locations = high_ind[indices]
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/neuron_loc_{k+1}.npy')
#     np.save(file_path, neuron_locations)
#     sc = MinMaxScaler()
#     sc = sc.fit(load_X[train_indices])
#     transformed_X = sc.transform(load_X)

#     ### Generate input sequences to a SHRED model
#     all_data_in = np.zeros((new_m - lags, lags, num_neurons))
#     for i in range(len(all_data_in)):
#         all_data_in[i] = transformed_X[i:i+lags, neuron_locations]

#     ### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
#     device = 'cuda' if torch.cuda.is_available() else 'cpu'

#     train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
#     valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
#     test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

#     ### -1 to have output be at the same time as final sensor measurements
#     train_data_out = torch.tensor(transformed_X[train_indices + lags - 1], dtype=torch.float32).to(device)
#     valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1], dtype=torch.float32).to(device)
#     test_data_out = torch.tensor(transformed_X[test_indices + lags - 1], dtype=torch.float32).to(device)

#     train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
#     valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
#     test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

#     shred = sindy_shred.SINDy_SHRED(num_neurons, n, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
#                                     library_dim=library_dim, poly_order=poly_order,
#                                     include_sine=include_sine, dt=dt, sindy = False, layer_norm=False).to(device)

#     validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
#                                         lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=0.0,
#                                         optimizer="AdamW", thres_epoch=100)
    
#     test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
#     test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
#     mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
#     print('mse test', mse_test)
#     train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
#     train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
#     mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
#     print('mse train', mse_train)


#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_recon_{k+1}.npy')
#     np.save(file_path, train_recons)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_recon_{k+1}.npy')
#     np.save(file_path, test_recons)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_gt_{k+1}.npy')
#     np.save(file_path, train_ground_truth)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_gt_{k+1}.npy')
#     np.save(file_path, test_ground_truth)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/mse_{k+1}.npy')
#     np.save(file_path, [mse_train, mse_test])





# ## low variance
# for k in range(25):
#     # Randomly select the neurons to train the SHRED model on
#     indices = np.random.choice(low_ind.shape[0], size= num_neurons, replace=False) 
#     neuron_locations = low_ind[indices]
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/neuron_loc_{k+1}.npy')
#     np.save(file_path, neuron_locations)
#     sc = MinMaxScaler()
#     sc = sc.fit(load_X[train_indices])
#     transformed_X = sc.transform(load_X)

#     ### Generate input sequences to a SHRED model
#     all_data_in = np.zeros((new_m - lags, lags, num_neurons))
#     for i in range(len(all_data_in)):
#         all_data_in[i] = transformed_X[i:i+lags, neuron_locations]

#     ### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
#     device = 'cuda' if torch.cuda.is_available() else 'cpu'

#     train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
#     valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
#     test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

#     ### -1 to have output be at the same time as final sensor measurements
#     train_data_out = torch.tensor(transformed_X[train_indices + lags - 1], dtype=torch.float32).to(device)
#     valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1], dtype=torch.float32).to(device)
#     test_data_out = torch.tensor(transformed_X[test_indices + lags - 1], dtype=torch.float32).to(device)

#     train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
#     valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
#     test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

#     shred = sindy_shred.SINDy_SHRED(num_neurons, n, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
#                                     library_dim=library_dim, poly_order=poly_order,
#                                     include_sine=include_sine, dt=dt, layer_norm=False, sindy = False).to(device)

#     validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
#                                         lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=0.0,
#                                         optimizer="AdamW", thres_epoch=100)
    
#     test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
#     test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
#     mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
#     print('mse test', mse_test)
#     train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
#     train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
#     mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
#     print('mse train', mse_train)


#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/train_recon_{k+1}.npy')
#     np.save(file_path, train_recons)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/test_recon_{k+1}.npy')
#     np.save(file_path, test_recons)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/train_gt_{k+1}.npy')
#     np.save(file_path, train_ground_truth)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/test_gt_{k+1}.npy')
#     np.save(file_path, test_ground_truth)
#     file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/mse_{k+1}.npy')
#     np.save(file_path, [mse_train, mse_test])






## random

for k in range(5,25):
    # Randomly select the neurons to train the SHRED model on
    neuron_locations = np.random.choice(n, size= num_neurons, replace=False) 

    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/neuron_loc_{k+1}.npy')
    np.save(file_path, neuron_locations)
    sc = MinMaxScaler()
    sc = sc.fit(load_X[train_indices])
    transformed_X = sc.transform(load_X)

    ### Generate input sequences to a SHRED model
    all_data_in = np.zeros((new_m - lags, lags, num_neurons))
    for i in range(len(all_data_in)):
        all_data_in[i] = transformed_X[i:i+lags, neuron_locations]

    ### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
    valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
    test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

    ### -1 to have output be at the same time as final sensor measurements
    train_data_out = torch.tensor(transformed_X[train_indices + lags - 1], dtype=torch.float32).to(device)
    valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1], dtype=torch.float32).to(device)
    test_data_out = torch.tensor(transformed_X[test_indices + lags - 1], dtype=torch.float32).to(device)

    train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
    valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
    test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

    shred = sindy_shred.SINDy_SHRED(num_neurons, n, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
                                    library_dim=library_dim, poly_order=poly_order,
                                    include_sine=include_sine, dt=dt, layer_norm=False, sindy = False).to(device)

    validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
                                        lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=0.0,
                                        optimizer="AdamW", thres_epoch=100)
    
    test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
    test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
    mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
    print('mse test', mse_test)
    train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
    train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
    mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
    print('mse train', mse_train)


    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/train_recon_{k+1}.npy')
    np.save(file_path, train_recons)
    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/test_recon_{k+1}.npy')
    np.save(file_path, test_recons)
    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/train_gt_{k+1}.npy')
    np.save(file_path, train_ground_truth)
    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/test_gt_{k+1}.npy')
    np.save(file_path, test_ground_truth)
    file_path = os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/mse_{k+1}.npy')
    np.save(file_path, [mse_train, mse_test])
# Out:
# 627
# 0.1145718856360712
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/vw/0t6vz1wn6rn5mgpcy6w188x00000gn/T/ipykernel_96321/3732988825.py:29: SyntaxWarning: invalid escape sequence '\s'
#   plt.scatter(neuron_index, var, color = 'black', label = '$\sigma$')
# /var/folders/vw/0t6vz1wn6rn5mgpcy6w188x00000gn/T/ipykernel_96321/3732988825.py:32: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma$', fontsize = 16)
# number high variance neurons 33
# number low variance neurons 76
# 1 : tensor(0.1166, grad_fn=<AddBackward0>)
# 2 : tensor(0.0714, grad_fn=<AddBackward0>)
# 3 : tensor(0.0531, grad_fn=<AddBackward0>)
# 4 : tensor(0.0431, grad_fn=<AddBackward0>)
# 5 : tensor(0.0442, grad_fn=<AddBackward0>)
# 6 : tensor(0.0457, grad_fn=<AddBackward0>)
# 7 : tensor(0.0453, grad_fn=<AddBackward0>)
# 8 : tensor(0.0439, grad_fn=<AddBackward0>)
# 9 : tensor(0.0407, grad_fn=<AddBackward0>)
# 10 : tensor(0.0385, grad_fn=<AddBackward0>)
# 11 : tensor(0.0349, grad_fn=<AddBackward0>)
# 12 : tensor(0.0293, grad_fn=<AddBackward0>)
# 13 : tensor(0.0245, grad_fn=<AddBackward0>)
# 14 : tensor(0.0234, grad_fn=<AddBackward0>)
# 15 : tensor(0.0218, grad_fn=<AddBackward0>)
# 16 : tensor(0.0217, grad_fn=<AddBackward0>)
# 17 : tensor(0.0212, grad_fn=<AddBackward0>)
# 18 : tensor(0.0210, grad_fn=<AddBackward0>)
# 19 : tensor(0.0211, grad_fn=<AddBackward0>)
# 20 : tensor(0.0208, grad_fn=<AddBackward0>)
# 21 : tensor(0.0201, grad_fn=<AddBackward0>)
# 22 : tensor(0.0198, grad_fn=<AddBackward0>)
# 23 : tensor(0.0192, grad_fn=<AddBackward0>)
# 24 : tensor(0.0191, grad_fn=<AddBackward0>)
# 25 : tensor(0.0195, grad_fn=<AddBackward0>)
# 26 : tensor(0.0200, grad_fn=<AddBackward0>)
# 27 : tensor(0.0189, grad_fn=<AddBackward0>)
# 28 : tensor(0.0191, grad_fn=<AddBackward0>)
# 29 : tensor(0.0196, grad_fn=<AddBackward0>)
# 30 : tensor(0.0189, grad_fn=<AddBackward0>)
# 31 : tensor(0.0184, grad_fn=<AddBackward0>)
# 32 : tensor(0.0183, grad_fn=<AddBackward0>)
# 33 : tensor(0.0180, grad_fn=<AddBackward0>)
# 34 : tensor(0.0180, grad_fn=<AddBackward0>)
# 35 : tensor(0.0174, grad_fn=<AddBackward0>)
# 36 : tensor(0.0174, grad_fn=<AddBackward0>)
# 37 : tensor(0.0172, grad_fn=<AddBackward0>)
# 38 : tensor(0.0172, grad_fn=<AddBackward0>)
# 39 : tensor(0.0171, grad_fn=<AddBackward0>)
# 40 : tensor(0.0164, grad_fn=<AddBackward0>)
# 41 : tensor(0.0167, grad_fn=<AddBackward0>)
# 42 : tensor(0.0165, grad_fn=<AddBackward0>)
# 43 : tensor(0.0160, grad_fn=<AddBackward0>)
# 44 : tensor(0.0182, grad_fn=<AddBackward0>)
# 45 : tensor(0.0215, grad_fn=<AddBackward0>)
# 46 : tensor(0.0203, grad_fn=<AddBackward0>)
# 47 : tensor(0.0173, grad_fn=<AddBackward0>)
# 48 : tensor(0.0180, grad_fn=<AddBackward0>)
# 49 : tensor(0.0176, grad_fn=<AddBackward0>)
# 50 : tensor(0.0180, grad_fn=<AddBackward0>)
# 51 : tensor(0.0168, grad_fn=<AddBackward0>)
# 52 : tensor(0.0163, grad_fn=<AddBackward0>)
# 53 : tensor(0.0157, grad_fn=<AddBackward0>)
# 54 : tensor(0.0161, grad_fn=<AddBackward0>)
# 55 : tensor(0.0160, grad_fn=<AddBackward0>)
# 56 : tensor(0.0160, grad_fn=<AddBackward0>)
# 57 : tensor(0.0157, grad_fn=<AddBackward0>)
# 58 : tensor(0.0155, grad_fn=<AddBackward0>)
# 59 : tensor(0.0157, grad_fn=<AddBackward0>)
# 60 : tensor(0.0154, grad_fn=<AddBackward0>)
# 61 : tensor(0.0154, grad_fn=<AddBackward0>)
# 62 : tensor(0.0160, grad_fn=<AddBackward0>)
# 63 : tensor(0.0157, grad_fn=<AddBackward0>)
# 64 : tensor(0.0160, grad_fn=<AddBackward0>)
# 65 : tensor(0.0151, grad_fn=<AddBackward0>)
# 66 : tensor(0.0162, grad_fn=<AddBackward0>)
# 67 : tensor(0.0156, grad_fn=<AddBackward0>)
# 68 : tensor(0.0153, grad_fn=<AddBackward0>)
# 69 : tensor(0.0152, grad_fn=<AddBackward0>)
# 70 : tensor(0.0158, grad_fn=<AddBackward0>)
# 71 : tensor(0.0162, grad_fn=<AddBackward0>)
# 72 : tensor(0.0157, grad_fn=<AddBackward0>)
# 73 : tensor(0.0191, grad_fn=<AddBackward0>)
# 74 : tensor(0.0187, grad_fn=<AddBackward0>)
# 75 : tensor(0.0210, grad_fn=<AddBackward0>)
# 76 : tensor(0.0152, grad_fn=<AddBackward0>)
# 77 : tensor(0.0158, grad_fn=<AddBackward0>)
# 78 : tensor(0.0152, grad_fn=<AddBackward0>)
# 79 : tensor(0.0141, grad_fn=<AddBackward0>)
# 80 : tensor(0.0145, grad_fn=<AddBackward0>)
# 81 : tensor(0.0141, grad_fn=<AddBackward0>)
# 82 : tensor(0.0138, grad_fn=<AddBackward0>)
# 83 : tensor(0.0136, grad_fn=<AddBackward0>)
# 84 : tensor(0.0139, grad_fn=<AddBackward0>)
# 85 : tensor(0.0135, grad_fn=<AddBackward0>)
# 86 : tensor(0.0136, grad_fn=<AddBackward0>)
# 87 : tensor(0.0138, grad_fn=<AddBackward0>)
# 88 : tensor(0.0140, grad_fn=<AddBackward0>)
# 89 : tensor(0.0134, grad_fn=<AddBackward0>)
# 90 : tensor(0.0140, grad_fn=<AddBackward0>)
# 91 : tensor(0.0154, grad_fn=<AddBackward0>)
# 92 : tensor(0.0158, grad_fn=<AddBackward0>)
# 93 : tensor(0.0144, grad_fn=<AddBackward0>)
# 94 : tensor(0.0134, grad_fn=<AddBackward0>)
# 95 : tensor(0.0137, grad_fn=<AddBackward0>)
# 96 : tensor(0.0145, grad_fn=<AddBackward0>)
# 97 : tensor(0.0142, grad_fn=<AddBackward0>)
# 98 : tensor(0.0154, grad_fn=<AddBackward0>)
# 99 : tensor(0.0159, grad_fn=<AddBackward0>)
# 100 : tensor(0.0153, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.3661)
# 101 : tensor(0.0164, grad_fn=<AddBackward0>)
# 102 : tensor(0.0145, grad_fn=<AddBackward0>)
# 103 : tensor(0.0144, grad_fn=<AddBackward0>)
# 104 : tensor(0.0130, grad_fn=<AddBackward0>)
# 105 : tensor(0.0135, grad_fn=<AddBackward0>)
# 106 : tensor(0.0141, grad_fn=<AddBackward0>)
# 107 : tensor(0.0137, grad_fn=<AddBackward0>)
# 108 : tensor(0.0139, grad_fn=<AddBackward0>)
# 109 : tensor(0.0131, grad_fn=<AddBackward0>)
# 110 : tensor(0.0134, grad_fn=<AddBackward0>)
# 111 : tensor(0.0145, grad_fn=<AddBackward0>)
# 112 : tensor(0.0139, grad_fn=<AddBackward0>)
# 113 : tensor(0.0144, grad_fn=<AddBackward0>)
# 114 : tensor(0.0143, grad_fn=<AddBackward0>)
# 115 : tensor(0.0143, grad_fn=<AddBackward0>)
# 116 : tensor(0.0135, grad_fn=<AddBackward0>)
# 117 : tensor(0.0133, grad_fn=<AddBackward0>)
# 118 : tensor(0.0131, grad_fn=<AddBackward0>)
# 119 : tensor(0.0132, grad_fn=<AddBackward0>)
# 120 : tensor(0.0125, grad_fn=<AddBackward0>)
# 121 : tensor(0.0127, grad_fn=<AddBackward0>)
# 122 : tensor(0.0124, grad_fn=<AddBackward0>)
# 123 : tensor(0.0130, grad_fn=<AddBackward0>)
# 124 : tensor(0.0131, grad_fn=<AddBackward0>)
# 125 : tensor(0.0132, grad_fn=<AddBackward0>)
# 126 : tensor(0.0123, grad_fn=<AddBackward0>)
# 127 : tensor(0.0125, grad_fn=<AddBackward0>)
# 128 : tensor(0.0125, grad_fn=<AddBackward0>)
# 129 : tensor(0.0133, grad_fn=<AddBackward0>)
# 130 : tensor(0.0138, grad_fn=<AddBackward0>)
# 131 : tensor(0.0130, grad_fn=<AddBackward0>)
# 132 : tensor(0.0131, grad_fn=<AddBackward0>)
# 133 : tensor(0.0136, grad_fn=<AddBackward0>)
# 134 : tensor(0.0135, grad_fn=<AddBackward0>)
# 135 : tensor(0.0135, grad_fn=<AddBackward0>)
# 136 : tensor(0.0123, grad_fn=<AddBackward0>)
# 137 : tensor(0.0133, grad_fn=<AddBackward0>)
# 138 : tensor(0.0132, grad_fn=<AddBackward0>)
# 139 : tensor(0.0148, grad_fn=<AddBackward0>)
# 140 : tensor(0.0132, grad_fn=<AddBackward0>)
# 141 : tensor(0.0127, grad_fn=<AddBackward0>)
# 142 : tensor(0.0126, grad_fn=<AddBackward0>)
# 143 : tensor(0.0127, grad_fn=<AddBackward0>)
# 144 : tensor(0.0118, grad_fn=<AddBackward0>)
# 145 : tensor(0.0119, grad_fn=<AddBackward0>)
# 146 : tensor(0.0119, grad_fn=<AddBackward0>)
# 147 : tensor(0.0121, grad_fn=<AddBackward0>)
# 148 : tensor(0.0125, grad_fn=<AddBackward0>)
# 149 : tensor(0.0128, grad_fn=<AddBackward0>)
# 150 : tensor(0.0133, grad_fn=<AddBackward0>)
# 151 : tensor(0.0121, grad_fn=<AddBackward0>)
# 152 : tensor(0.0124, grad_fn=<AddBackward0>)
# 153 : tensor(0.0127, grad_fn=<AddBackward0>)
# 154 : tensor(0.0121, grad_fn=<AddBackward0>)
# 155 : tensor(0.0123, grad_fn=<AddBackward0>)
# 156 : tensor(0.0118, grad_fn=<AddBackward0>)
# 157 : tensor(0.0121, grad_fn=<AddBackward0>)
# 158 : tensor(0.0121, grad_fn=<AddBackward0>)
# 159 : tensor(0.0119, grad_fn=<AddBackward0>)
# 160 : tensor(0.0121, grad_fn=<AddBackward0>)
# 161 : tensor(0.0122, grad_fn=<AddBackward0>)
# 162 : tensor(0.0114, grad_fn=<AddBackward0>)
# 163 : tensor(0.0135, grad_fn=<AddBackward0>)
# 164 : tensor(0.0127, grad_fn=<AddBackward0>)
# 165 : tensor(0.0135, grad_fn=<AddBackward0>)
# 166 : tensor(0.0127, grad_fn=<AddBackward0>)
# 167 : tensor(0.0127, grad_fn=<AddBackward0>)
# 168 : tensor(0.0120, grad_fn=<AddBackward0>)
# 169 : tensor(0.0123, grad_fn=<AddBackward0>)
# 170 : tensor(0.0116, grad_fn=<AddBackward0>)
# 171 : tensor(0.0117, grad_fn=<AddBackward0>)
# 172 : tensor(0.0125, grad_fn=<AddBackward0>)
# 173 : tensor(0.0127, grad_fn=<AddBackward0>)
# 174 : tensor(0.0155, grad_fn=<AddBackward0>)
# 175 : tensor(0.0128, grad_fn=<AddBackward0>)
# 176 : tensor(0.0130, grad_fn=<AddBackward0>)
# 177 : tensor(0.0124, grad_fn=<AddBackward0>)
# 178 : tensor(0.0123, grad_fn=<AddBackward0>)
# 179 : tensor(0.0120, grad_fn=<AddBackward0>)
# 180 : tensor(0.0121, grad_fn=<AddBackward0>)
# 181 : tensor(0.0137, grad_fn=<AddBackward0>)
# 182 : tensor(0.0129, grad_fn=<AddBackward0>)
# 183 : tensor(0.0136, grad_fn=<AddBackward0>)
# 184 : tensor(0.0141, grad_fn=<AddBackward0>)
# 185 : tensor(0.0133, grad_fn=<AddBackward0>)
# 186 : tensor(0.0142, grad_fn=<AddBackward0>)
# 187 : tensor(0.0116, grad_fn=<AddBackward0>)
# 188 : tensor(0.0123, grad_fn=<AddBackward0>)
# 189 : tensor(0.0118, grad_fn=<AddBackward0>)
# 190 : tensor(0.0125, grad_fn=<AddBackward0>)
# 191 : tensor(0.0120, grad_fn=<AddBackward0>)
# 192 : tensor(0.0119, grad_fn=<AddBackward0>)
# 193 : tensor(0.0116, grad_fn=<AddBackward0>)
# 194 : tensor(0.0115, grad_fn=<AddBackward0>)
# 195 : tensor(0.0122, grad_fn=<AddBackward0>)
# 196 : tensor(0.0117, grad_fn=<AddBackward0>)
# 197 : tensor(0.0120, grad_fn=<AddBackward0>)
# 198 : tensor(0.0107, grad_fn=<AddBackward0>)
# 199 : tensor(0.0114, grad_fn=<AddBackward0>)
# 200 : tensor(0.0116, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.3948)
# mse test 0.6431372
# mse train 0.21578637
# 1 : tensor(0.1049, grad_fn=<AddBackward0>)
# 2 : tensor(0.0660, grad_fn=<AddBackward0>)
# 3 : tensor(0.0529, grad_fn=<AddBackward0>)
# 4 : tensor(0.0422, grad_fn=<AddBackward0>)
# 5 : tensor(0.0444, grad_fn=<AddBackward0>)
# 6 : tensor(0.0475, grad_fn=<AddBackward0>)
# 7 : tensor(0.0466, grad_fn=<AddBackward0>)
# 8 : tensor(0.0454, grad_fn=<AddBackward0>)
# 9 : tensor(0.0442, grad_fn=<AddBackward0>)
# 10 : tensor(0.0424, grad_fn=<AddBackward0>)
# 11 : tensor(0.0397, grad_fn=<AddBackward0>)
# 12 : tensor(0.0362, grad_fn=<AddBackward0>)
# 13 : tensor(0.0316, grad_fn=<AddBackward0>)
# 14 : tensor(0.0307, grad_fn=<AddBackward0>)
# 15 : tensor(0.0284, grad_fn=<AddBackward0>)
# 16 : tensor(0.0276, grad_fn=<AddBackward0>)
# 17 : tensor(0.0272, grad_fn=<AddBackward0>)
# 18 : tensor(0.0274, grad_fn=<AddBackward0>)
# 19 : tensor(0.0275, grad_fn=<AddBackward0>)
# 20 : tensor(0.0270, grad_fn=<AddBackward0>)
# 21 : tensor(0.0272, grad_fn=<AddBackward0>)
# 22 : tensor(0.0271, grad_fn=<AddBackward0>)
# 23 : tensor(0.0269, grad_fn=<AddBackward0>)
# 24 : tensor(0.0266, grad_fn=<AddBackward0>)
# 25 : tensor(0.0264, grad_fn=<AddBackward0>)
# 26 : tensor(0.0261, grad_fn=<AddBackward0>)
# 27 : tensor(0.0259, grad_fn=<AddBackward0>)
# 28 : tensor(0.0259, grad_fn=<AddBackward0>)
# 29 : tensor(0.0261, grad_fn=<AddBackward0>)
# 30 : tensor(0.0253, grad_fn=<AddBackward0>)
# 31 : tensor(0.0247, grad_fn=<AddBackward0>)
# 32 : tensor(0.0249, grad_fn=<AddBackward0>)
# 33 : tensor(0.0240, grad_fn=<AddBackward0>)
# 34 : tensor(0.0236, grad_fn=<AddBackward0>)
# 35 : tensor(0.0235, grad_fn=<AddBackward0>)
# 36 : tensor(0.0229, grad_fn=<AddBackward0>)
# 37 : tensor(0.0227, grad_fn=<AddBackward0>)
# 38 : tensor(0.0216, grad_fn=<AddBackward0>)
# 39 : tensor(0.0216, grad_fn=<AddBackward0>)
# 40 : tensor(0.0210, grad_fn=<AddBackward0>)
# 41 : tensor(0.0205, grad_fn=<AddBackward0>)
# 42 : tensor(0.0207, grad_fn=<AddBackward0>)
# 43 : tensor(0.0196, grad_fn=<AddBackward0>)
# 44 : tensor(0.0193, grad_fn=<AddBackward0>)
# 45 : tensor(0.0189, grad_fn=<AddBackward0>)
# 46 : tensor(0.0186, grad_fn=<AddBackward0>)
# 47 : tensor(0.0190, grad_fn=<AddBackward0>)
# 48 : tensor(0.0186, grad_fn=<AddBackward0>)
# 49 : tensor(0.0175, grad_fn=<AddBackward0>)
# 50 : tensor(0.0185, grad_fn=<AddBackward0>)
# 51 : tensor(0.0195, grad_fn=<AddBackward0>)
# 52 : tensor(0.0185, grad_fn=<AddBackward0>)
# 53 : tensor(0.0178, grad_fn=<AddBackward0>)
# 54 : tensor(0.0178, grad_fn=<AddBackward0>)
# 55 : tensor(0.0173, grad_fn=<AddBackward0>)
# 56 : tensor(0.0220, grad_fn=<AddBackward0>)
# 57 : tensor(0.0209, grad_fn=<AddBackward0>)
# 58 : tensor(0.0173, grad_fn=<AddBackward0>)
# 59 : tensor(0.0172, grad_fn=<AddBackward0>)
# 60 : tensor(0.0200, grad_fn=<AddBackward0>)
# 61 : tensor(0.0262, grad_fn=<AddBackward0>)
# 62 : tensor(0.0158, grad_fn=<AddBackward0>)
# 63 : tensor(0.0156, grad_fn=<AddBackward0>)
# 64 : tensor(0.0179, grad_fn=<AddBackward0>)
# 65 : tensor(0.0157, grad_fn=<AddBackward0>)
# 66 : tensor(0.0167, grad_fn=<AddBackward0>)
# 67 : tensor(0.0154, grad_fn=<AddBackward0>)
# 68 : tensor(0.0149, grad_fn=<AddBackward0>)
# 69 : tensor(0.0157, grad_fn=<AddBackward0>)
# 70 : tensor(0.0156, grad_fn=<AddBackward0>)
# 71 : tensor(0.0147, grad_fn=<AddBackward0>)
# 72 : tensor(0.0154, grad_fn=<AddBackward0>)
# 73 : tensor(0.0145, grad_fn=<AddBackward0>)
# 74 : tensor(0.0148, grad_fn=<AddBackward0>)
# 75 : tensor(0.0144, grad_fn=<AddBackward0>)
# 76 : tensor(0.0164, grad_fn=<AddBackward0>)
# 77 : tensor(0.0145, grad_fn=<AddBackward0>)
# 78 : tensor(0.0149, grad_fn=<AddBackward0>)
# 79 : tensor(0.0159, grad_fn=<AddBackward0>)
# 80 : tensor(0.0146, grad_fn=<AddBackward0>)
# 81 : tensor(0.0150, grad_fn=<AddBackward0>)
# 82 : tensor(0.0184, grad_fn=<AddBackward0>)
# 83 : tensor(0.0148, grad_fn=<AddBackward0>)
# 84 : tensor(0.0157, grad_fn=<AddBackward0>)
# 85 : tensor(0.0154, grad_fn=<AddBackward0>)
# 86 : tensor(0.0173, grad_fn=<AddBackward0>)
# 87 : tensor(0.0179, grad_fn=<AddBackward0>)
# 88 : tensor(0.0146, grad_fn=<AddBackward0>)
# 89 : tensor(0.0157, grad_fn=<AddBackward0>)
# 90 : tensor(0.0190, grad_fn=<AddBackward0>)
# 91 : tensor(0.0154, grad_fn=<AddBackward0>)
# 92 : tensor(0.0146, grad_fn=<AddBackward0>)
# 93 : tensor(0.0147, grad_fn=<AddBackward0>)
# 94 : tensor(0.0151, grad_fn=<AddBackward0>)
# 95 : tensor(0.0146, grad_fn=<AddBackward0>)
# 96 : tensor(0.0141, grad_fn=<AddBackward0>)
# 97 : tensor(0.0132, grad_fn=<AddBackward0>)
# 98 : tensor(0.0130, grad_fn=<AddBackward0>)
# 99 : tensor(0.0131, grad_fn=<AddBackward0>)
# 100 : tensor(0.0136, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.5099)
# 101 : tensor(0.0132, grad_fn=<AddBackward0>)
# 102 : tensor(0.0133, grad_fn=<AddBackward0>)
# 103 : tensor(0.0131, grad_fn=<AddBackward0>)
# 104 : tensor(0.0127, grad_fn=<AddBackward0>)
# 105 : tensor(0.0126, grad_fn=<AddBackward0>)
# 106 : tensor(0.0136, grad_fn=<AddBackward0>)
# 107 : tensor(0.0149, grad_fn=<AddBackward0>)
# 108 : tensor(0.0136, grad_fn=<AddBackward0>)
# 109 : tensor(0.0126, grad_fn=<AddBackward0>)
# 110 : tensor(0.0163, grad_fn=<AddBackward0>)
# 111 : tensor(0.0146, grad_fn=<AddBackward0>)
# 112 : tensor(0.0155, grad_fn=<AddBackward0>)
# 113 : tensor(0.0126, grad_fn=<AddBackward0>)
# 114 : tensor(0.0135, grad_fn=<AddBackward0>)
# 115 : tensor(0.0141, grad_fn=<AddBackward0>)
# 116 : tensor(0.0147, grad_fn=<AddBackward0>)
# 117 : tensor(0.0144, grad_fn=<AddBackward0>)
# 118 : tensor(0.0130, grad_fn=<AddBackward0>)
# 119 : tensor(0.0126, grad_fn=<AddBackward0>)
# 120 : tensor(0.0139, grad_fn=<AddBackward0>)
# 121 : tensor(0.0142, grad_fn=<AddBackward0>)
# 122 : tensor(0.0131, grad_fn=<AddBackward0>)
# 123 : tensor(0.0133, grad_fn=<AddBackward0>)
# 124 : tensor(0.0126, grad_fn=<AddBackward0>)
# 125 : tensor(0.0127, grad_fn=<AddBackward0>)
# 126 : tensor(0.0124, grad_fn=<AddBackward0>)
# 127 : tensor(0.0133, grad_fn=<AddBackward0>)
# 128 : tensor(0.0131, grad_fn=<AddBackward0>)
# 129 : tensor(0.0119, grad_fn=<AddBackward0>)
# 130 : tensor(0.0128, grad_fn=<AddBackward0>)
# 131 : tensor(0.0124, grad_fn=<AddBackward0>)
# 132 : tensor(0.0123, grad_fn=<AddBackward0>)
# 133 : tensor(0.0131, grad_fn=<AddBackward0>)
# 134 : tensor(0.0122, grad_fn=<AddBackward0>)
# 135 : tensor(0.0122, grad_fn=<AddBackward0>)
# 136 : tensor(0.0121, grad_fn=<AddBackward0>)
# 137 : tensor(0.0123, grad_fn=<AddBackward0>)
# 138 : tensor(0.0121, grad_fn=<AddBackward0>)
# 139 : tensor(0.0134, grad_fn=<AddBackward0>)
# 140 : tensor(0.0123, grad_fn=<AddBackward0>)
# 141 : tensor(0.0120, grad_fn=<AddBackward0>)
# 142 : tensor(0.0133, grad_fn=<AddBackward0>)
# 143 : tensor(0.0129, grad_fn=<AddBackward0>)
# 144 : tensor(0.0127, grad_fn=<AddBackward0>)
# 145 : tensor(0.0124, grad_fn=<AddBackward0>)
# 146 : tensor(0.0128, grad_fn=<AddBackward0>)
# 147 : tensor(0.0145, grad_fn=<AddBackward0>)
# 148 : tensor(0.0137, grad_fn=<AddBackward0>)
# 149 : tensor(0.0135, grad_fn=<AddBackward0>)
# 150 : tensor(0.0126, grad_fn=<AddBackward0>)
# 151 : tensor(0.0132, grad_fn=<AddBackward0>)
# 152 : tensor(0.0135, grad_fn=<AddBackward0>)
# 153 : tensor(0.0148, grad_fn=<AddBackward0>)
# 154 : tensor(0.0125, grad_fn=<AddBackward0>)
# 155 : tensor(0.0122, grad_fn=<AddBackward0>)
# 156 : tensor(0.0120, grad_fn=<AddBackward0>)
# 157 : tensor(0.0119, grad_fn=<AddBackward0>)
# 158 : tensor(0.0115, grad_fn=<AddBackward0>)
# 159 : tensor(0.0117, grad_fn=<AddBackward0>)
# 160 : tensor(0.0115, grad_fn=<AddBackward0>)
# 161 : tensor(0.0116, grad_fn=<AddBackward0>)
# 162 : tensor(0.0112, grad_fn=<AddBackward0>)
# 163 : tensor(0.0121, grad_fn=<AddBackward0>)
# 164 : tensor(0.0126, grad_fn=<AddBackward0>)
# 165 : tensor(0.0134, grad_fn=<AddBackward0>)
# 166 : tensor(0.0121, grad_fn=<AddBackward0>)
# 167 : tensor(0.0129, grad_fn=<AddBackward0>)
# 168 : tensor(0.0119, grad_fn=<AddBackward0>)
# 169 : tensor(0.0115, grad_fn=<AddBackward0>)
# 170 : tensor(0.0124, grad_fn=<AddBackward0>)
# 171 : tensor(0.0121, grad_fn=<AddBackward0>)
# 172 : tensor(0.0138, grad_fn=<AddBackward0>)
# 173 : tensor(0.0118, grad_fn=<AddBackward0>)
# 174 : tensor(0.0133, grad_fn=<AddBackward0>)
# 175 : tensor(0.0115, grad_fn=<AddBackward0>)
# 176 : tensor(0.0117, grad_fn=<AddBackward0>)
# 177 : tensor(0.0113, grad_fn=<AddBackward0>)
# 178 : tensor(0.0116, grad_fn=<AddBackward0>)
# 179 : tensor(0.0124, grad_fn=<AddBackward0>)
# 180 : tensor(0.0114, grad_fn=<AddBackward0>)
# 181 : tensor(0.0125, grad_fn=<AddBackward0>)
# 182 : tensor(0.0110, grad_fn=<AddBackward0>)
# 183 : tensor(0.0117, grad_fn=<AddBackward0>)
# 184 : tensor(0.0113, grad_fn=<AddBackward0>)
# 185 : tensor(0.0107, grad_fn=<AddBackward0>)
# 186 : tensor(0.0111, grad_fn=<AddBackward0>)
# 187 : tensor(0.0112, grad_fn=<AddBackward0>)
# 188 : tensor(0.0138, grad_fn=<AddBackward0>)
# 189 : tensor(0.0122, grad_fn=<AddBackward0>)
# 190 : tensor(0.0134, grad_fn=<AddBackward0>)
# 191 : tensor(0.0121, grad_fn=<AddBackward0>)
# 192 : tensor(0.0126, grad_fn=<AddBackward0>)
# 193 : tensor(0.0119, grad_fn=<AddBackward0>)
# 194 : tensor(0.0124, grad_fn=<AddBackward0>)
# 195 : tensor(0.0119, grad_fn=<AddBackward0>)
# 196 : tensor(0.0109, grad_fn=<AddBackward0>)
# 197 : tensor(0.0118, grad_fn=<AddBackward0>)
# 198 : tensor(0.0110, grad_fn=<AddBackward0>)
# 199 : tensor(0.0127, grad_fn=<AddBackward0>)
# 200 : tensor(0.0109, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.4990)
# mse test 0.58367854
# mse train 0.18670969
# 1 : tensor(0.1071, grad_fn=<AddBackward0>)
# 2 : tensor(0.0711, grad_fn=<AddBackward0>)
# 3 : tensor(0.0533, grad_fn=<AddBackward0>)
# 4 : tensor(0.0432, grad_fn=<AddBackward0>)
# 5 : tensor(0.0446, grad_fn=<AddBackward0>)
# 6 : tensor(0.0471, grad_fn=<AddBackward0>)
# 7 : tensor(0.0467, grad_fn=<AddBackward0>)
# 8 : tensor(0.0457, grad_fn=<AddBackward0>)
# 9 : tensor(0.0450, grad_fn=<AddBackward0>)
# 10 : tensor(0.0441, grad_fn=<AddBackward0>)
# 11 : tensor(0.0443, grad_fn=<AddBackward0>)
# 12 : tensor(0.0445, grad_fn=<AddBackward0>)
# 13 : tensor(0.0441, grad_fn=<AddBackward0>)
# 14 : tensor(0.0433, grad_fn=<AddBackward0>)
# 15 : tensor(0.0431, grad_fn=<AddBackward0>)
# 16 : tensor(0.0428, grad_fn=<AddBackward0>)
# 17 : tensor(0.0421, grad_fn=<AddBackward0>)
# 18 : tensor(0.0406, grad_fn=<AddBackward0>)
# 19 : tensor(0.0399, grad_fn=<AddBackward0>)
# 20 : tensor(0.0371, grad_fn=<AddBackward0>)
# 21 : tensor(0.0338, grad_fn=<AddBackward0>)
# 22 : tensor(0.0299, grad_fn=<AddBackward0>)
# 23 : tensor(0.0260, grad_fn=<AddBackward0>)
# 24 : tensor(0.0238, grad_fn=<AddBackward0>)
# 25 : tensor(0.0230, grad_fn=<AddBackward0>)
# 26 : tensor(0.0235, grad_fn=<AddBackward0>)
# 27 : tensor(0.0214, grad_fn=<AddBackward0>)
# 28 : tensor(0.0233, grad_fn=<AddBackward0>)
# 29 : tensor(0.0214, grad_fn=<AddBackward0>)
# 30 : tensor(0.0229, grad_fn=<AddBackward0>)
# 31 : tensor(0.0206, grad_fn=<AddBackward0>)
# 32 : tensor(0.0228, grad_fn=<AddBackward0>)
# 33 : tensor(0.0199, grad_fn=<AddBackward0>)
# 34 : tensor(0.0219, grad_fn=<AddBackward0>)
# 35 : tensor(0.0197, grad_fn=<AddBackward0>)
# 36 : tensor(0.0210, grad_fn=<AddBackward0>)
# 37 : tensor(0.0194, grad_fn=<AddBackward0>)
# 38 : tensor(0.0195, grad_fn=<AddBackward0>)
# 39 : tensor(0.0198, grad_fn=<AddBackward0>)
# 40 : tensor(0.0184, grad_fn=<AddBackward0>)
# 41 : tensor(0.0207, grad_fn=<AddBackward0>)
# 42 : tensor(0.0180, grad_fn=<AddBackward0>)
# 43 : tensor(0.0213, grad_fn=<AddBackward0>)
# 44 : tensor(0.0176, grad_fn=<AddBackward0>)
# 45 : tensor(0.0194, grad_fn=<AddBackward0>)
# 46 : tensor(0.0170, grad_fn=<AddBackward0>)
# 47 : tensor(0.0172, grad_fn=<AddBackward0>)
# 48 : tensor(0.0175, grad_fn=<AddBackward0>)
# 49 : tensor(0.0166, grad_fn=<AddBackward0>)
# 50 : tensor(0.0188, grad_fn=<AddBackward0>)
# 51 : tensor(0.0160, grad_fn=<AddBackward0>)
# 52 : tensor(0.0201, grad_fn=<AddBackward0>)
# 53 : tensor(0.0166, grad_fn=<AddBackward0>)
# 54 : tensor(0.0170, grad_fn=<AddBackward0>)
# 55 : tensor(0.0158, grad_fn=<AddBackward0>)
# 56 : tensor(0.0157, grad_fn=<AddBackward0>)
# 57 : tensor(0.0163, grad_fn=<AddBackward0>)
# 58 : tensor(0.0148, grad_fn=<AddBackward0>)
# 59 : tensor(0.0165, grad_fn=<AddBackward0>)
# 60 : tensor(0.0150, grad_fn=<AddBackward0>)
# 61 : tensor(0.0184, grad_fn=<AddBackward0>)
# 62 : tensor(0.0145, grad_fn=<AddBackward0>)
# 63 : tensor(0.0182, grad_fn=<AddBackward0>)
# 64 : tensor(0.0152, grad_fn=<AddBackward0>)
# 65 : tensor(0.0170, grad_fn=<AddBackward0>)
# 66 : tensor(0.0146, grad_fn=<AddBackward0>)
# 67 : tensor(0.0160, grad_fn=<AddBackward0>)
# 68 : tensor(0.0148, grad_fn=<AddBackward0>)
# 69 : tensor(0.0164, grad_fn=<AddBackward0>)
# 70 : tensor(0.0144, grad_fn=<AddBackward0>)
# 71 : tensor(0.0176, grad_fn=<AddBackward0>)
# 72 : tensor(0.0148, grad_fn=<AddBackward0>)
# 73 : tensor(0.0168, grad_fn=<AddBackward0>)
# 74 : tensor(0.0298, grad_fn=<AddBackward0>)
# 75 : tensor(0.0145, grad_fn=<AddBackward0>)
# 76 : tensor(0.0155, grad_fn=<AddBackward0>)
# 77 : tensor(0.0160, grad_fn=<AddBackward0>)
# 78 : tensor(0.0175, grad_fn=<AddBackward0>)
# 79 : tensor(0.0199, grad_fn=<AddBackward0>)
# 80 : tensor(0.0149, grad_fn=<AddBackward0>)
# 81 : tensor(0.0161, grad_fn=<AddBackward0>)
# 82 : tensor(0.0146, grad_fn=<AddBackward0>)
# 83 : tensor(0.0162, grad_fn=<AddBackward0>)
# 84 : tensor(0.0142, grad_fn=<AddBackward0>)
# 85 : tensor(0.0177, grad_fn=<AddBackward0>)
# 86 : tensor(0.0139, grad_fn=<AddBackward0>)
# 87 : tensor(0.0170, grad_fn=<AddBackward0>)
# 88 : tensor(0.0138, grad_fn=<AddBackward0>)
# 89 : tensor(0.0166, grad_fn=<AddBackward0>)
# 90 : tensor(0.0138, grad_fn=<AddBackward0>)
# 91 : tensor(0.0151, grad_fn=<AddBackward0>)
# 92 : tensor(0.0141, grad_fn=<AddBackward0>)
# 93 : tensor(0.0145, grad_fn=<AddBackward0>)
# 94 : tensor(0.0150, grad_fn=<AddBackward0>)
# 95 : tensor(0.0143, grad_fn=<AddBackward0>)
# 96 : tensor(0.0144, grad_fn=<AddBackward0>)
# 97 : tensor(0.0135, grad_fn=<AddBackward0>)
# 98 : tensor(0.0153, grad_fn=<AddBackward0>)
# 99 : tensor(0.0136, grad_fn=<AddBackward0>)
# 100 : tensor(0.0145, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.4428)
# 101 : tensor(0.0133, grad_fn=<AddBackward0>)
# 102 : tensor(0.0146, grad_fn=<AddBackward0>)
# 103 : tensor(0.0135, grad_fn=<AddBackward0>)
# 104 : tensor(0.0138, grad_fn=<AddBackward0>)
# 105 : tensor(0.0130, grad_fn=<AddBackward0>)
# 106 : tensor(0.0136, grad_fn=<AddBackward0>)
# 107 : tensor(0.0128, grad_fn=<AddBackward0>)
# 108 : tensor(0.0131, grad_fn=<AddBackward0>)
# 109 : tensor(0.0128, grad_fn=<AddBackward0>)
# 110 : tensor(0.0128, grad_fn=<AddBackward0>)
# 111 : tensor(0.0128, grad_fn=<AddBackward0>)
# 112 : tensor(0.0128, grad_fn=<AddBackward0>)
# 113 : tensor(0.0125, grad_fn=<AddBackward0>)
# 114 : tensor(0.0128, grad_fn=<AddBackward0>)
# 115 : tensor(0.0122, grad_fn=<AddBackward0>)
# 116 : tensor(0.0136, grad_fn=<AddBackward0>)
# 117 : tensor(0.0123, grad_fn=<AddBackward0>)
# 118 : tensor(0.0141, grad_fn=<AddBackward0>)
# 119 : tensor(0.0126, grad_fn=<AddBackward0>)
# 120 : tensor(0.0168, grad_fn=<AddBackward0>)
# 121 : tensor(0.0128, grad_fn=<AddBackward0>)
# 122 : tensor(0.0169, grad_fn=<AddBackward0>)
# 123 : tensor(0.0143, grad_fn=<AddBackward0>)
# 124 : tensor(0.0136, grad_fn=<AddBackward0>)
# 125 : tensor(0.0139, grad_fn=<AddBackward0>)
# 126 : tensor(0.0128, grad_fn=<AddBackward0>)
# 127 : tensor(0.0120, grad_fn=<AddBackward0>)
# 128 : tensor(0.0121, grad_fn=<AddBackward0>)
# 129 : tensor(0.0123, grad_fn=<AddBackward0>)
# 130 : tensor(0.0115, grad_fn=<AddBackward0>)
# 131 : tensor(0.0117, grad_fn=<AddBackward0>)
# 132 : tensor(0.0114, grad_fn=<AddBackward0>)
# 133 : tensor(0.0113, grad_fn=<AddBackward0>)
# 134 : tensor(0.0111, grad_fn=<AddBackward0>)
# 135 : tensor(0.0110, grad_fn=<AddBackward0>)
# 136 : tensor(0.0112, grad_fn=<AddBackward0>)
# 137 : tensor(0.0112, grad_fn=<AddBackward0>)
# 138 : tensor(0.0109, grad_fn=<AddBackward0>)
# 139 : tensor(0.0114, grad_fn=<AddBackward0>)
# 140 : tensor(0.0111, grad_fn=<AddBackward0>)
# 141 : tensor(0.0113, grad_fn=<AddBackward0>)
# 142 : tensor(0.0110, grad_fn=<AddBackward0>)
# 143 : tensor(0.0113, grad_fn=<AddBackward0>)
# 144 : tensor(0.0109, grad_fn=<AddBackward0>)
# 145 : tensor(0.0109, grad_fn=<AddBackward0>)
# 146 : tensor(0.0114, grad_fn=<AddBackward0>)
# 147 : tensor(0.0110, grad_fn=<AddBackward0>)
# 148 : tensor(0.0111, grad_fn=<AddBackward0>)
# 149 : tensor(0.0107, grad_fn=<AddBackward0>)
# 150 : tensor(0.0110, grad_fn=<AddBackward0>)
# 151 : tensor(0.0107, grad_fn=<AddBackward0>)
# 152 : tensor(0.0110, grad_fn=<AddBackward0>)
# 153 : tensor(0.0108, grad_fn=<AddBackward0>)
# 154 : tensor(0.0108, grad_fn=<AddBackward0>)
# 155 : tensor(0.0112, grad_fn=<AddBackward0>)
# 156 : tensor(0.0105, grad_fn=<AddBackward0>)
# 157 : tensor(0.0110, grad_fn=<AddBackward0>)
# 158 : tensor(0.0111, grad_fn=<AddBackward0>)
# 159 : tensor(0.0147, grad_fn=<AddBackward0>)
# 160 : tensor(0.0121, grad_fn=<AddBackward0>)
# 161 : tensor(0.0358, grad_fn=<AddBackward0>)
# 162 : tensor(0.0143, grad_fn=<AddBackward0>)
# 163 : tensor(0.0149, grad_fn=<AddBackward0>)
# 164 : tensor(0.0118, grad_fn=<AddBackward0>)
# 165 : tensor(0.0116, grad_fn=<AddBackward0>)
# 166 : tensor(0.0124, grad_fn=<AddBackward0>)
# 167 : tensor(0.0113, grad_fn=<AddBackward0>)
# 168 : tensor(0.0111, grad_fn=<AddBackward0>)
# 169 : tensor(0.0110, grad_fn=<AddBackward0>)
# 170 : tensor(0.0108, grad_fn=<AddBackward0>)
# 171 : tensor(0.0105, grad_fn=<AddBackward0>)
# 172 : tensor(0.0100, grad_fn=<AddBackward0>)
# 173 : tensor(0.0105, grad_fn=<AddBackward0>)
# 174 : tensor(0.0100, grad_fn=<AddBackward0>)
# 175 : tensor(0.0102, grad_fn=<AddBackward0>)
# 176 : tensor(0.0102, grad_fn=<AddBackward0>)
# 177 : tensor(0.0101, grad_fn=<AddBackward0>)
# 178 : tensor(0.0101, grad_fn=<AddBackward0>)
# 179 : tensor(0.0100, grad_fn=<AddBackward0>)
# 180 : tensor(0.0101, grad_fn=<AddBackward0>)
# 181 : tensor(0.0101, grad_fn=<AddBackward0>)
# 182 : tensor(0.0099, grad_fn=<AddBackward0>)
# 183 : tensor(0.0102, grad_fn=<AddBackward0>)
# 184 : tensor(0.0102, grad_fn=<AddBackward0>)
# 185 : tensor(0.0101, grad_fn=<AddBackward0>)
# 186 : tensor(0.0102, grad_fn=<AddBackward0>)
# 187 : tensor(0.0100, grad_fn=<AddBackward0>)
# 188 : tensor(0.0099, grad_fn=<AddBackward0>)
# 189 : tensor(0.0101, grad_fn=<AddBackward0>)
# 190 : tensor(0.0102, grad_fn=<AddBackward0>)
# 191 : tensor(0.0097, grad_fn=<AddBackward0>)
# 192 : tensor(0.0096, grad_fn=<AddBackward0>)
# 193 : tensor(0.0097, grad_fn=<AddBackward0>)
# 194 : tensor(0.0098, grad_fn=<AddBackward0>)
# 195 : tensor(0.0096, grad_fn=<AddBackward0>)
# 196 : tensor(0.0101, grad_fn=<AddBackward0>)
# 197 : tensor(0.0098, grad_fn=<AddBackward0>)
# 198 : tensor(0.0101, grad_fn=<AddBackward0>)
# 199 : tensor(0.0100, grad_fn=<AddBackward0>)
# 200 : tensor(0.0100, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.4380)
# mse test 0.71079725
# mse train 0.2080197
# 1 : tensor(0.1106, grad_fn=<AddBackward0>)
# 2 : tensor(0.0720, grad_fn=<AddBackward0>)
# 3 : tensor(0.0535, grad_fn=<AddBackward0>)
# 4 : tensor(0.0439, grad_fn=<AddBackward0>)
# 5 : tensor(0.0447, grad_fn=<AddBackward0>)
# 6 : tensor(0.0478, grad_fn=<AddBackward0>)
# 7 : tensor(0.0469, grad_fn=<AddBackward0>)
# 8 : tensor(0.0460, grad_fn=<AddBackward0>)
# 9 : tensor(0.0455, grad_fn=<AddBackward0>)
# 10 : tensor(0.0446, grad_fn=<AddBackward0>)
# 11 : tensor(0.0451, grad_fn=<AddBackward0>)
# 12 : tensor(0.0450, grad_fn=<AddBackward0>)
# 13 : tensor(0.0446, grad_fn=<AddBackward0>)
# 14 : tensor(0.0448, grad_fn=<AddBackward0>)
# 15 : tensor(0.0445, grad_fn=<AddBackward0>)
# 16 : tensor(0.0444, grad_fn=<AddBackward0>)
# 17 : tensor(0.0440, grad_fn=<AddBackward0>)
# 18 : tensor(0.0434, grad_fn=<AddBackward0>)
# 19 : tensor(0.0431, grad_fn=<AddBackward0>)
# 20 : tensor(0.0419, grad_fn=<AddBackward0>)
# 21 : tensor(0.0403, grad_fn=<AddBackward0>)
# 22 : tensor(0.0386, grad_fn=<AddBackward0>)
# 23 : tensor(0.0372, grad_fn=<AddBackward0>)
# 24 : tensor(0.0366, grad_fn=<AddBackward0>)
# 25 : tensor(0.0360, grad_fn=<AddBackward0>)
# 26 : tensor(0.0351, grad_fn=<AddBackward0>)
# 27 : tensor(0.0337, grad_fn=<AddBackward0>)
# 28 : tensor(0.0340, grad_fn=<AddBackward0>)
# 29 : tensor(0.0339, grad_fn=<AddBackward0>)
# 30 : tensor(0.0337, grad_fn=<AddBackward0>)
# 31 : tensor(0.0337, grad_fn=<AddBackward0>)
# 32 : tensor(0.0336, grad_fn=<AddBackward0>)
# 33 : tensor(0.0337, grad_fn=<AddBackward0>)
# 34 : tensor(0.0336, grad_fn=<AddBackward0>)
# 35 : tensor(0.0341, grad_fn=<AddBackward0>)
# 36 : tensor(0.0336, grad_fn=<AddBackward0>)
# 37 : tensor(0.0325, grad_fn=<AddBackward0>)
# 38 : tensor(0.0335, grad_fn=<AddBackward0>)
# 39 : tensor(0.0356, grad_fn=<AddBackward0>)
# 40 : tensor(0.0335, grad_fn=<AddBackward0>)
# 41 : tensor(0.0324, grad_fn=<AddBackward0>)
# 42 : tensor(0.0335, grad_fn=<AddBackward0>)
# 43 : tensor(0.0348, grad_fn=<AddBackward0>)
# 44 : tensor(0.0317, grad_fn=<AddBackward0>)
# 45 : tensor(0.0322, grad_fn=<AddBackward0>)
# 46 : tensor(0.0326, grad_fn=<AddBackward0>)
# 47 : tensor(0.0321, grad_fn=<AddBackward0>)
# 48 : tensor(0.0317, grad_fn=<AddBackward0>)
# 49 : tensor(0.0329, grad_fn=<AddBackward0>)
# 50 : tensor(0.0322, grad_fn=<AddBackward0>)
# 51 : tensor(0.0315, grad_fn=<AddBackward0>)
# 52 : tensor(0.0309, grad_fn=<AddBackward0>)
# 53 : tensor(0.0326, grad_fn=<AddBackward0>)
# 54 : tensor(0.0317, grad_fn=<AddBackward0>)
# 55 : tensor(0.0310, grad_fn=<AddBackward0>)
# 56 : tensor(0.0304, grad_fn=<AddBackward0>)
# 57 : tensor(0.0316, grad_fn=<AddBackward0>)
# 58 : tensor(0.0313, grad_fn=<AddBackward0>)
# 59 : tensor(0.0306, grad_fn=<AddBackward0>)
# 60 : tensor(0.0299, grad_fn=<AddBackward0>)
# 61 : tensor(0.0319, grad_fn=<AddBackward0>)
# 62 : tensor(0.0301, grad_fn=<AddBackward0>)
# 63 : tensor(0.0292, grad_fn=<AddBackward0>)
# 64 : tensor(0.0300, grad_fn=<AddBackward0>)
# 65 : tensor(0.0298, grad_fn=<AddBackward0>)
# 66 : tensor(0.0288, grad_fn=<AddBackward0>)
# 67 : tensor(0.0292, grad_fn=<AddBackward0>)
# 68 : tensor(0.0290, grad_fn=<AddBackward0>)
# 69 : tensor(0.0294, grad_fn=<AddBackward0>)
# 70 : tensor(0.0273, grad_fn=<AddBackward0>)
# 71 : tensor(0.0281, grad_fn=<AddBackward0>)
# 72 : tensor(0.0276, grad_fn=<AddBackward0>)
# 73 : tensor(0.0276, grad_fn=<AddBackward0>)
# 74 : tensor(0.0266, grad_fn=<AddBackward0>)
# 75 : tensor(0.0269, grad_fn=<AddBackward0>)
# 76 : tensor(0.0260, grad_fn=<AddBackward0>)
# 77 : tensor(0.0262, grad_fn=<AddBackward0>)
# 78 : tensor(0.0253, grad_fn=<AddBackward0>)
# 79 : tensor(0.0247, grad_fn=<AddBackward0>)
# 80 : tensor(0.0251, grad_fn=<AddBackward0>)
# 81 : tensor(0.0233, grad_fn=<AddBackward0>)
# 82 : tensor(0.0240, grad_fn=<AddBackward0>)
# 83 : tensor(0.0218, grad_fn=<AddBackward0>)
# 84 : tensor(0.0233, grad_fn=<AddBackward0>)
# 85 : tensor(0.0212, grad_fn=<AddBackward0>)
# 86 : tensor(0.0244, grad_fn=<AddBackward0>)
# 87 : tensor(0.0212, grad_fn=<AddBackward0>)
# 88 : tensor(0.0242, grad_fn=<AddBackward0>)
# 89 : tensor(0.0218, grad_fn=<AddBackward0>)
# 90 : tensor(0.0227, grad_fn=<AddBackward0>)
# 91 : tensor(0.0210, grad_fn=<AddBackward0>)
# 92 : tensor(0.0212, grad_fn=<AddBackward0>)
# 93 : tensor(0.0202, grad_fn=<AddBackward0>)
# 94 : tensor(0.0201, grad_fn=<AddBackward0>)
# 95 : tensor(0.0191, grad_fn=<AddBackward0>)
# 96 : tensor(0.0206, grad_fn=<AddBackward0>)
# 97 : tensor(0.0191, grad_fn=<AddBackward0>)
# 98 : tensor(0.0202, grad_fn=<AddBackward0>)
# 99 : tensor(0.0199, grad_fn=<AddBackward0>)
# 100 : tensor(0.0196, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.4966)
# 101 : tensor(0.0193, grad_fn=<AddBackward0>)
# 102 : tensor(0.0202, grad_fn=<AddBackward0>)
# 103 : tensor(0.0204, grad_fn=<AddBackward0>)
# 104 : tensor(0.0197, grad_fn=<AddBackward0>)
# 105 : tensor(0.0190, grad_fn=<AddBackward0>)
# 106 : tensor(0.0186, grad_fn=<AddBackward0>)
# 107 : tensor(0.0186, grad_fn=<AddBackward0>)
# 108 : tensor(0.0183, grad_fn=<AddBackward0>)
# 109 : tensor(0.0188, grad_fn=<AddBackward0>)
# 110 : tensor(0.0177, grad_fn=<AddBackward0>)
# 111 : tensor(0.0191, grad_fn=<AddBackward0>)
# 112 : tensor(0.0182, grad_fn=<AddBackward0>)
# 113 : tensor(0.0175, grad_fn=<AddBackward0>)
# 114 : tensor(0.0187, grad_fn=<AddBackward0>)
# 115 : tensor(0.0170, grad_fn=<AddBackward0>)
# 116 : tensor(0.0175, grad_fn=<AddBackward0>)
# 117 : tensor(0.0195, grad_fn=<AddBackward0>)
# 118 : tensor(0.0168, grad_fn=<AddBackward0>)
# 119 : tensor(0.0177, grad_fn=<AddBackward0>)
# 120 : tensor(0.0189, grad_fn=<AddBackward0>)
# 121 : tensor(0.0203, grad_fn=<AddBackward0>)
# 122 : tensor(0.0181, grad_fn=<AddBackward0>)
# 123 : tensor(0.0179, grad_fn=<AddBackward0>)
# 124 : tensor(0.0189, grad_fn=<AddBackward0>)
# 125 : tensor(0.0175, grad_fn=<AddBackward0>)
# 126 : tensor(0.0162, grad_fn=<AddBackward0>)
# 127 : tensor(0.0182, grad_fn=<AddBackward0>)
# 128 : tensor(0.0164, grad_fn=<AddBackward0>)
# 129 : tensor(0.0162, grad_fn=<AddBackward0>)
# 130 : tensor(0.0180, grad_fn=<AddBackward0>)
# 131 : tensor(0.0154, grad_fn=<AddBackward0>)
# 132 : tensor(0.0165, grad_fn=<AddBackward0>)
# 133 : tensor(0.0152, grad_fn=<AddBackward0>)
# 134 : tensor(0.0166, grad_fn=<AddBackward0>)
# 135 : tensor(0.0158, grad_fn=<AddBackward0>)
# 136 : tensor(0.0143, grad_fn=<AddBackward0>)
# 137 : tensor(0.0164, grad_fn=<AddBackward0>)
# 138 : tensor(0.0146, grad_fn=<AddBackward0>)
# 139 : tensor(0.0146, grad_fn=<AddBackward0>)
# 140 : tensor(0.0150, grad_fn=<AddBackward0>)
# 141 : tensor(0.0140, grad_fn=<AddBackward0>)
# 142 : tensor(0.0139, grad_fn=<AddBackward0>)
# 143 : tensor(0.0140, grad_fn=<AddBackward0>)
# 144 : tensor(0.0138, grad_fn=<AddBackward0>)
# 145 : tensor(0.0136, grad_fn=<AddBackward0>)
# 146 : tensor(0.0131, grad_fn=<AddBackward0>)
# 147 : tensor(0.0141, grad_fn=<AddBackward0>)
# 148 : tensor(0.0137, grad_fn=<AddBackward0>)
# 149 : tensor(0.0123, grad_fn=<AddBackward0>)
# 150 : tensor(0.0149, grad_fn=<AddBackward0>)
# 151 : tensor(0.0128, grad_fn=<AddBackward0>)
# 152 : tensor(0.0131, grad_fn=<AddBackward0>)
# 153 : tensor(0.0140, grad_fn=<AddBackward0>)
# 154 : tensor(0.0121, grad_fn=<AddBackward0>)
# 155 : tensor(0.0133, grad_fn=<AddBackward0>)
# 156 : tensor(0.0127, grad_fn=<AddBackward0>)
# 157 : tensor(0.0132, grad_fn=<AddBackward0>)
# 158 : tensor(0.0124, grad_fn=<AddBackward0>)
# 159 : tensor(0.0120, grad_fn=<AddBackward0>)
# 160 : tensor(0.0114, grad_fn=<AddBackward0>)
# 161 : tensor(0.0125, grad_fn=<AddBackward0>)
# 162 : tensor(0.0114, grad_fn=<AddBackward0>)
# 163 : tensor(0.0119, grad_fn=<AddBackward0>)
# 164 : tensor(0.0178, grad_fn=<AddBackward0>)
# 165 : tensor(0.0127, grad_fn=<AddBackward0>)
# 166 : tensor(0.0164, grad_fn=<AddBackward0>)
# 167 : tensor(0.0115, grad_fn=<AddBackward0>)
# 168 : tensor(0.0126, grad_fn=<AddBackward0>)
# 169 : tensor(0.0117, grad_fn=<AddBackward0>)
# 170 : tensor(0.0115, grad_fn=<AddBackward0>)
# 171 : tensor(0.0114, grad_fn=<AddBackward0>)
# 172 : tensor(0.0111, grad_fn=<AddBackward0>)
# 173 : tensor(0.0112, grad_fn=<AddBackward0>)
# 174 : tensor(0.0109, grad_fn=<AddBackward0>)
# 175 : tensor(0.0119, grad_fn=<AddBackward0>)
# 176 : tensor(0.0110, grad_fn=<AddBackward0>)
# 177 : tensor(0.0111, grad_fn=<AddBackward0>)
# 178 : tensor(0.0101, grad_fn=<AddBackward0>)
# 179 : tensor(0.0110, grad_fn=<AddBackward0>)
# 180 : tensor(0.0100, grad_fn=<AddBackward0>)
# 181 : tensor(0.0102, grad_fn=<AddBackward0>)
# 182 : tensor(0.0101, grad_fn=<AddBackward0>)
# 183 : tensor(0.0098, grad_fn=<AddBackward0>)
# 184 : tensor(0.0105, grad_fn=<AddBackward0>)
# 185 : tensor(0.0099, grad_fn=<AddBackward0>)
# 186 : tensor(0.0100, grad_fn=<AddBackward0>)
# 187 : tensor(0.0103, grad_fn=<AddBackward0>)
# 188 : tensor(0.0102, grad_fn=<AddBackward0>)
# 189 : tensor(0.0101, grad_fn=<AddBackward0>)
# 190 : tensor(0.0100, grad_fn=<AddBackward0>)
# 191 : tensor(0.0097, grad_fn=<AddBackward0>)
# 192 : tensor(0.0104, grad_fn=<AddBackward0>)
# 193 : tensor(0.0096, grad_fn=<AddBackward0>)
# 194 : tensor(0.0110, grad_fn=<AddBackward0>)
# 195 : tensor(0.0098, grad_fn=<AddBackward0>)
# 196 : tensor(0.0104, grad_fn=<AddBackward0>)
# 197 : tensor(0.0108, grad_fn=<AddBackward0>)
# 198 : tensor(0.0097, grad_fn=<AddBackward0>)
# 199 : tensor(0.0114, grad_fn=<AddBackward0>)
# 200 : tensor(0.0105, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.6113)
# mse test 0.9373391
# mse train 0.20496817
# 1 : tensor(0.0966, grad_fn=<AddBackward0>)
# 2 : tensor(0.0664, grad_fn=<AddBackward0>)
# 3 : tensor(0.0500, grad_fn=<AddBackward0>)
# 4 : tensor(0.0418, grad_fn=<AddBackward0>)
# 5 : tensor(0.0451, grad_fn=<AddBackward0>)
# 6 : tensor(0.0478, grad_fn=<AddBackward0>)
# 7 : tensor(0.0473, grad_fn=<AddBackward0>)
# 8 : tensor(0.0452, grad_fn=<AddBackward0>)
# 9 : tensor(0.0442, grad_fn=<AddBackward0>)
# 10 : tensor(0.0446, grad_fn=<AddBackward0>)
# 11 : tensor(0.0446, grad_fn=<AddBackward0>)
# 12 : tensor(0.0446, grad_fn=<AddBackward0>)
# 13 : tensor(0.0440, grad_fn=<AddBackward0>)
# 14 : tensor(0.0435, grad_fn=<AddBackward0>)
# 15 : tensor(0.0429, grad_fn=<AddBackward0>)
# 16 : tensor(0.0421, grad_fn=<AddBackward0>)
# 17 : tensor(0.0408, grad_fn=<AddBackward0>)
# 18 : tensor(0.0382, grad_fn=<AddBackward0>)
# 19 : tensor(0.0364, grad_fn=<AddBackward0>)
# 20 : tensor(0.0332, grad_fn=<AddBackward0>)
# 21 : tensor(0.0320, grad_fn=<AddBackward0>)
# 22 : tensor(0.0296, grad_fn=<AddBackward0>)
# 23 : tensor(0.0273, grad_fn=<AddBackward0>)
# 24 : tensor(0.0244, grad_fn=<AddBackward0>)
# 25 : tensor(0.0228, grad_fn=<AddBackward0>)
# 26 : tensor(0.0208, grad_fn=<AddBackward0>)
# 27 : tensor(0.0204, grad_fn=<AddBackward0>)
# 28 : tensor(0.0198, grad_fn=<AddBackward0>)
# 29 : tensor(0.0206, grad_fn=<AddBackward0>)
# 30 : tensor(0.0192, grad_fn=<AddBackward0>)
# 31 : tensor(0.0193, grad_fn=<AddBackward0>)
# 32 : tensor(0.0178, grad_fn=<AddBackward0>)
# 33 : tensor(0.0182, grad_fn=<AddBackward0>)
# 34 : tensor(0.0176, grad_fn=<AddBackward0>)
# 35 : tensor(0.0231, grad_fn=<AddBackward0>)
# 36 : tensor(0.0246, grad_fn=<AddBackward0>)
# 37 : tensor(0.0189, grad_fn=<AddBackward0>)
# 38 : tensor(0.0192, grad_fn=<AddBackward0>)
# 39 : tensor(0.0196, grad_fn=<AddBackward0>)
# 40 : tensor(0.0180, grad_fn=<AddBackward0>)
# 41 : tensor(0.0173, grad_fn=<AddBackward0>)
# 42 : tensor(0.0156, grad_fn=<AddBackward0>)
# 43 : tensor(0.0165, grad_fn=<AddBackward0>)
# 44 : tensor(0.0154, grad_fn=<AddBackward0>)
# 45 : tensor(0.0160, grad_fn=<AddBackward0>)
# 46 : tensor(0.0147, grad_fn=<AddBackward0>)
# 47 : tensor(0.0163, grad_fn=<AddBackward0>)
# 48 : tensor(0.0150, grad_fn=<AddBackward0>)
# 49 : tensor(0.0163, grad_fn=<AddBackward0>)
# 50 : tensor(0.0147, grad_fn=<AddBackward0>)
# 51 : tensor(0.0152, grad_fn=<AddBackward0>)
# 52 : tensor(0.0169, grad_fn=<AddBackward0>)
# 53 : tensor(0.0168, grad_fn=<AddBackward0>)
# 54 : tensor(0.0228, grad_fn=<AddBackward0>)
# 55 : tensor(0.0202, grad_fn=<AddBackward0>)
# 56 : tensor(0.0147, grad_fn=<AddBackward0>)
# 57 : tensor(0.0148, grad_fn=<AddBackward0>)
# 58 : tensor(0.0142, grad_fn=<AddBackward0>)
# 59 : tensor(0.0145, grad_fn=<AddBackward0>)
# 60 : tensor(0.0144, grad_fn=<AddBackward0>)
# 61 : tensor(0.0147, grad_fn=<AddBackward0>)
# 62 : tensor(0.0144, grad_fn=<AddBackward0>)
# 63 : tensor(0.0133, grad_fn=<AddBackward0>)
# 64 : tensor(0.0138, grad_fn=<AddBackward0>)
# 65 : tensor(0.0146, grad_fn=<AddBackward0>)
# 66 : tensor(0.0131, grad_fn=<AddBackward0>)
# 67 : tensor(0.0142, grad_fn=<AddBackward0>)
# 68 : tensor(0.0127, grad_fn=<AddBackward0>)
# 69 : tensor(0.0132, grad_fn=<AddBackward0>)
# 70 : tensor(0.0127, grad_fn=<AddBackward0>)
# 71 : tensor(0.0128, grad_fn=<AddBackward0>)
# 72 : tensor(0.0127, grad_fn=<AddBackward0>)
# 73 : tensor(0.0129, grad_fn=<AddBackward0>)
# 74 : tensor(0.0131, grad_fn=<AddBackward0>)
# 75 : tensor(0.0121, grad_fn=<AddBackward0>)
# 76 : tensor(0.0118, grad_fn=<AddBackward0>)
# 77 : tensor(0.0123, grad_fn=<AddBackward0>)
# 78 : tensor(0.0120, grad_fn=<AddBackward0>)
# 79 : tensor(0.0123, grad_fn=<AddBackward0>)
# 80 : tensor(0.0116, grad_fn=<AddBackward0>)
# 81 : tensor(0.0118, grad_fn=<AddBackward0>)
# 82 : tensor(0.0120, grad_fn=<AddBackward0>)
# 83 : tensor(0.0121, grad_fn=<AddBackward0>)
# 84 : tensor(0.0124, grad_fn=<AddBackward0>)
# 85 : tensor(0.0132, grad_fn=<AddBackward0>)
# 86 : tensor(0.0171, grad_fn=<AddBackward0>)
# 87 : tensor(0.0166, grad_fn=<AddBackward0>)
# 88 : tensor(0.0123, grad_fn=<AddBackward0>)
# 89 : tensor(0.0119, grad_fn=<AddBackward0>)
# 90 : tensor(0.0125, grad_fn=<AddBackward0>)
# 91 : tensor(0.0107, grad_fn=<AddBackward0>)
# 92 : tensor(0.0107, grad_fn=<AddBackward0>)
# 93 : tensor(0.0112, grad_fn=<AddBackward0>)
# 94 : tensor(0.0108, grad_fn=<AddBackward0>)
# 95 : tensor(0.0110, grad_fn=<AddBackward0>)
# 96 : tensor(0.0116, grad_fn=<AddBackward0>)
# 97 : tensor(0.0168, grad_fn=<AddBackward0>)
# 98 : tensor(0.0138, grad_fn=<AddBackward0>)
# 99 : tensor(0.0146, grad_fn=<AddBackward0>)
# 100 : tensor(0.0142, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.4662)
# 101 : tensor(0.0113, grad_fn=<AddBackward0>)
# 102 : tensor(0.0111, grad_fn=<AddBackward0>)
# 103 : tensor(0.0116, grad_fn=<AddBackward0>)
# 104 : tensor(0.0120, grad_fn=<AddBackward0>)
# 105 : tensor(0.0135, grad_fn=<AddBackward0>)
# 106 : tensor(0.0116, grad_fn=<AddBackward0>)
# 107 : tensor(0.0135, grad_fn=<AddBackward0>)
# 108 : tensor(0.0119, grad_fn=<AddBackward0>)
# 109 : tensor(0.0116, grad_fn=<AddBackward0>)
# 110 : tensor(0.0120, grad_fn=<AddBackward0>)
# 111 : tensor(0.0114, grad_fn=<AddBackward0>)
# 112 : tensor(0.0140, grad_fn=<AddBackward0>)
# 113 : tensor(0.0138, grad_fn=<AddBackward0>)
# 114 : tensor(0.0131, grad_fn=<AddBackward0>)
# 115 : tensor(0.0113, grad_fn=<AddBackward0>)
# 116 : tensor(0.0112, grad_fn=<AddBackward0>)
# 117 : tensor(0.0127, grad_fn=<AddBackward0>)
# 118 : tensor(0.0122, grad_fn=<AddBackward0>)
# 119 : tensor(0.0109, grad_fn=<AddBackward0>)
# 120 : tensor(0.0104, grad_fn=<AddBackward0>)
# 121 : tensor(0.0102, grad_fn=<AddBackward0>)
# 122 : tensor(0.0101, grad_fn=<AddBackward0>)
# 123 : tensor(0.0100, grad_fn=<AddBackward0>)
# 124 : tensor(0.0102, grad_fn=<AddBackward0>)
# 125 : tensor(0.0171, grad_fn=<AddBackward0>)
# 126 : tensor(0.0144, grad_fn=<AddBackward0>)
# 127 : tensor(0.0113, grad_fn=<AddBackward0>)
# 128 : tensor(0.0121, grad_fn=<AddBackward0>)
# 129 : tensor(0.0103, grad_fn=<AddBackward0>)
# 130 : tensor(0.0104, grad_fn=<AddBackward0>)
# 131 : tensor(0.0096, grad_fn=<AddBackward0>)
# 132 : tensor(0.0106, grad_fn=<AddBackward0>)
# 133 : tensor(0.0103, grad_fn=<AddBackward0>)
# 134 : tensor(0.0109, grad_fn=<AddBackward0>)
# 135 : tensor(0.0113, grad_fn=<AddBackward0>)
# 136 : tensor(0.0187, grad_fn=<AddBackward0>)
# 137 : tensor(0.0130, grad_fn=<AddBackward0>)
# 138 : tensor(0.0142, grad_fn=<AddBackward0>)
# 139 : tensor(0.0129, grad_fn=<AddBackward0>)
# 140 : tensor(0.0101, grad_fn=<AddBackward0>)
# 141 : tensor(0.0104, grad_fn=<AddBackward0>)
# 142 : tensor(0.0099, grad_fn=<AddBackward0>)
# 143 : tensor(0.0115, grad_fn=<AddBackward0>)
# 144 : tensor(0.0121, grad_fn=<AddBackward0>)
# 145 : tensor(0.0121, grad_fn=<AddBackward0>)
# 146 : tensor(0.0163, grad_fn=<AddBackward0>)
# 147 : tensor(0.0117, grad_fn=<AddBackward0>)
# 148 : tensor(0.0100, grad_fn=<AddBackward0>)
# 149 : tensor(0.0103, grad_fn=<AddBackward0>)
# 150 : tensor(0.0099, grad_fn=<AddBackward0>)
# 151 : tensor(0.0100, grad_fn=<AddBackward0>)
# 152 : tensor(0.0093, grad_fn=<AddBackward0>)
# 153 : tensor(0.0096, grad_fn=<AddBackward0>)
# 154 : tensor(0.0096, grad_fn=<AddBackward0>)
# 155 : tensor(0.0137, grad_fn=<AddBackward0>)
# 156 : tensor(0.0116, grad_fn=<AddBackward0>)
# 157 : tensor(0.0122, grad_fn=<AddBackward0>)
# 158 : tensor(0.0119, grad_fn=<AddBackward0>)
# 159 : tensor(0.0095, grad_fn=<AddBackward0>)
# 160 : tensor(0.0098, grad_fn=<AddBackward0>)
# 161 : tensor(0.0089, grad_fn=<AddBackward0>)
# 162 : tensor(0.0097, grad_fn=<AddBackward0>)
# 163 : tensor(0.0093, grad_fn=<AddBackward0>)
# 164 : tensor(0.0100, grad_fn=<AddBackward0>)
# 165 : tensor(0.0118, grad_fn=<AddBackward0>)
# 166 : tensor(0.0115, grad_fn=<AddBackward0>)
# 167 : tensor(0.0100, grad_fn=<AddBackward0>)
# 168 : tensor(0.0106, grad_fn=<AddBackward0>)
# 169 : tensor(0.0090, grad_fn=<AddBackward0>)
# 170 : tensor(0.0091, grad_fn=<AddBackward0>)
# 171 : tensor(0.0092, grad_fn=<AddBackward0>)
# 172 : tensor(0.0096, grad_fn=<AddBackward0>)
# 173 : tensor(0.0102, grad_fn=<AddBackward0>)
# 174 : tensor(0.0117, grad_fn=<AddBackward0>)
# 175 : tensor(0.0112, grad_fn=<AddBackward0>)
# 176 : tensor(0.0096, grad_fn=<AddBackward0>)
# 177 : tensor(0.0099, grad_fn=<AddBackward0>)
# 178 : tensor(0.0090, grad_fn=<AddBackward0>)
# 179 : tensor(0.0090, grad_fn=<AddBackward0>)
# 180 : tensor(0.0088, grad_fn=<AddBackward0>)
# 181 : tensor(0.0103, grad_fn=<AddBackward0>)
# 182 : tensor(0.0104, grad_fn=<AddBackward0>)
# 183 : tensor(0.0089, grad_fn=<AddBackward0>)
# 184 : tensor(0.0097, grad_fn=<AddBackward0>)
# 185 : tensor(0.0092, grad_fn=<AddBackward0>)
# 186 : tensor(0.0089, grad_fn=<AddBackward0>)
# 187 : tensor(0.0091, grad_fn=<AddBackward0>)
# 188 : tensor(0.0101, grad_fn=<AddBackward0>)
# 189 : tensor(0.0105, grad_fn=<AddBackward0>)
# 190 : tensor(0.0124, grad_fn=<AddBackward0>)
# 191 : tensor(0.0117, grad_fn=<AddBackward0>)
# 192 : tensor(0.0111, grad_fn=<AddBackward0>)
# 193 : tensor(0.0112, grad_fn=<AddBackward0>)
# 194 : tensor(0.0099, grad_fn=<AddBackward0>)
# 195 : tensor(0.0096, grad_fn=<AddBackward0>)
# 196 : tensor(0.0086, grad_fn=<AddBackward0>)
# 197 : tensor(0.0091, grad_fn=<AddBackward0>)
# 198 : tensor(0.0091, grad_fn=<AddBackward0>)
# 199 : tensor(0.0086, grad_fn=<AddBackward0>)
# 200 : tensor(0.0110, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.4306)
# mse test 0.7387526
# mse train 0.283439
# 1 : tensor(0.0988, grad_fn=<AddBackward0>)
# 2 : tensor(0.0598, grad_fn=<AddBackward0>)
# 3 : tensor(0.0501, grad_fn=<AddBackward0>)
# 4 : tensor(0.0415, grad_fn=<AddBackward0>)
# 5 : tensor(0.0445, grad_fn=<AddBackward0>)
# 6 : tensor(0.0476, grad_fn=<AddBackward0>)
# 7 : tensor(0.0472, grad_fn=<AddBackward0>)
# 8 : tensor(0.0440, grad_fn=<AddBackward0>)
# 9 : tensor(0.0432, grad_fn=<AddBackward0>)
# 10 : tensor(0.0422, grad_fn=<AddBackward0>)
# 11 : tensor(0.0414, grad_fn=<AddBackward0>)
# 12 : tensor(0.0387, grad_fn=<AddBackward0>)
# 13 : tensor(0.0356, grad_fn=<AddBackward0>)
# 14 : tensor(0.0345, grad_fn=<AddBackward0>)
# 15 : tensor(0.0331, grad_fn=<AddBackward0>)
# 16 : tensor(0.0316, grad_fn=<AddBackward0>)
# 17 : tensor(0.0313, grad_fn=<AddBackward0>)
# 18 : tensor(0.0312, grad_fn=<AddBackward0>)
# 19 : tensor(0.0314, grad_fn=<AddBackward0>)
# 20 : tensor(0.0311, grad_fn=<AddBackward0>)
# 21 : tensor(0.0308, grad_fn=<AddBackward0>)
# 22 : tensor(0.0302, grad_fn=<AddBackward0>)
# 23 : tensor(0.0299, grad_fn=<AddBackward0>)
# 24 : tensor(0.0296, grad_fn=<AddBackward0>)
# 25 : tensor(0.0296, grad_fn=<AddBackward0>)
# 26 : tensor(0.0289, grad_fn=<AddBackward0>)
# 27 : tensor(0.0286, grad_fn=<AddBackward0>)
# 28 : tensor(0.0288, grad_fn=<AddBackward0>)
# 29 : tensor(0.0281, grad_fn=<AddBackward0>)
# 30 : tensor(0.0281, grad_fn=<AddBackward0>)
# 31 : tensor(0.0276, grad_fn=<AddBackward0>)
# 32 : tensor(0.0276, grad_fn=<AddBackward0>)
# 33 : tensor(0.0268, grad_fn=<AddBackward0>)
# 34 : tensor(0.0263, grad_fn=<AddBackward0>)
# 35 : tensor(0.0264, grad_fn=<AddBackward0>)
# 36 : tensor(0.0262, grad_fn=<AddBackward0>)
# 37 : tensor(0.0261, grad_fn=<AddBackward0>)
# 38 : tensor(0.0259, grad_fn=<AddBackward0>)
# 39 : tensor(0.0256, grad_fn=<AddBackward0>)
# 40 : tensor(0.0255, grad_fn=<AddBackward0>)
# 41 : tensor(0.0254, grad_fn=<AddBackward0>)
# 42 : tensor(0.0250, grad_fn=<AddBackward0>)
# 43 : tensor(0.0253, grad_fn=<AddBackward0>)
# 44 : tensor(0.0251, grad_fn=<AddBackward0>)
# 45 : tensor(0.0252, grad_fn=<AddBackward0>)
# 46 : tensor(0.0248, grad_fn=<AddBackward0>)
# 47 : tensor(0.0248, grad_fn=<AddBackward0>)
# 48 : tensor(0.0245, grad_fn=<AddBackward0>)
# 49 : tensor(0.0246, grad_fn=<AddBackward0>)
# 50 : tensor(0.0243, grad_fn=<AddBackward0>)
# 51 : tensor(0.0242, grad_fn=<AddBackward0>)
# 52 : tensor(0.0239, grad_fn=<AddBackward0>)
# ...
# 48 : tensor(0.0249, grad_fn=<AddBackward0>)
# 49 : tensor(0.0371, grad_fn=<AddBackward0>)
# 50 : tensor(0.0207, grad_fn=<AddBackward0>)
# 51 : tensor(0.0184, grad_fn=<AddBackward0>)
# 52 : tensor(0.0201, grad_fn=<AddBackward0>)
# 53 : tensor(0.0221, grad_fn=<AddBackward0>)
# 54 : tensor(0.0209, grad_fn=<AddBackward0>)
# 55 : tensor(0.0215, grad_fn=<AddBackward0>)
# 56 : tensor(0.0184, grad_fn=<AddBackward0>)
# 57 : tensor(0.0191, grad_fn=<AddBackward0>)
# 58 : tensor(0.0182, grad_fn=<AddBackward0>)
# 59 : tensor(0.0193, grad_fn=<AddBackward0>)
# 60 : tensor(0.0183, grad_fn=<AddBackward0>)
# 61 : tensor(0.0178, grad_fn=<AddBackward0>)
# 62 : tensor(0.0199, grad_fn=<AddBackward0>)
# 63 : tensor(0.0182, grad_fn=<AddBackward0>)
# 64 : tensor(0.0190, grad_fn=<AddBackward0>)
# 65 : tensor(0.0177, grad_fn=<AddBackward0>)
# 66 : tensor(0.0170, grad_fn=<AddBackward0>)
# 67 : tensor(0.0182, grad_fn=<AddBackward0>)
# 68 : tensor(0.0168, grad_fn=<AddBackward0>)
# 69 : tensor(0.0181, grad_fn=<AddBackward0>)
# 70 : tensor(0.0167, grad_fn=<AddBackward0>)
# 71 : tensor(0.0168, grad_fn=<AddBackward0>)
# 72 : tensor(0.0207, grad_fn=<AddBackward0>)
# 73 : tensor(0.0176, grad_fn=<AddBackward0>)
# 74 : tensor(0.0248, grad_fn=<AddBackward0>)
# 75 : tensor(0.0225, grad_fn=<AddBackward0>)
# 76 : tensor(0.0253, grad_fn=<AddBackward0>)
# 77 : tensor(0.0319, grad_fn=<AddBackward0>)
# 78 : tensor(0.0172, grad_fn=<AddBackward0>)
# 79 : tensor(0.0172, grad_fn=<AddBackward0>)
# 80 : tensor(0.0173, grad_fn=<AddBackward0>)
# 81 : tensor(0.0169, grad_fn=<AddBackward0>)
# 82 : tensor(0.0165, grad_fn=<AddBackward0>)
# 83 : tensor(0.0162, grad_fn=<AddBackward0>)
# 84 : tensor(0.0157, grad_fn=<AddBackward0>)
# 85 : tensor(0.0181, grad_fn=<AddBackward0>)
# 86 : tensor(0.0173, grad_fn=<AddBackward0>)
# 87 : tensor(0.0184, grad_fn=<AddBackward0>)
# 88 : tensor(0.0172, grad_fn=<AddBackward0>)
# 89 : tensor(0.0179, grad_fn=<AddBackward0>)
# 90 : tensor(0.0175, grad_fn=<AddBackward0>)
# 91 : tensor(0.0151, grad_fn=<AddBackward0>)
# 92 : tensor(0.0190, grad_fn=<AddBackward0>)
# 93 : tensor(0.0156, grad_fn=<AddBackward0>)
# 94 : tensor(0.0159, grad_fn=<AddBackward0>)
# 95 : tensor(0.0220, grad_fn=<AddBackward0>)
# 96 : tensor(0.0157, grad_fn=<AddBackward0>)
# 97 : tensor(0.0210, grad_fn=<AddBackward0>)
# 98 : tensor(0.0199, grad_fn=<AddBackward0>)
# 99 : tensor(0.0149, grad_fn=<AddBackward0>)
# 100 : tensor(0.0153, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.4381)
# 101 : tensor(0.0150, grad_fn=<AddBackward0>)
# 102 : tensor(0.0149, grad_fn=<AddBackward0>)
# 103 : tensor(0.0145, grad_fn=<AddBackward0>)
# 104 : tensor(0.0137, grad_fn=<AddBackward0>)
# 105 : tensor(0.0150, grad_fn=<AddBackward0>)
# 106 : tensor(0.0147, grad_fn=<AddBackward0>)
# 107 : tensor(0.0187, grad_fn=<AddBackward0>)
# 108 : tensor(0.0140, grad_fn=<AddBackward0>)
# 109 : tensor(0.0146, grad_fn=<AddBackward0>)
# 110 : tensor(0.0133, grad_fn=<AddBackward0>)
# 111 : tensor(0.0131, grad_fn=<AddBackward0>)
# 112 : tensor(0.0131, grad_fn=<AddBackward0>)
# 113 : tensor(0.0136, grad_fn=<AddBackward0>)
# 114 : tensor(0.0138, grad_fn=<AddBackward0>)
# 115 : tensor(0.0146, grad_fn=<AddBackward0>)
# 116 : tensor(0.0154, grad_fn=<AddBackward0>)
# 117 : tensor(0.0235, grad_fn=<AddBackward0>)
# 118 : tensor(0.0146, grad_fn=<AddBackward0>)
# 119 : tensor(0.0149, grad_fn=<AddBackward0>)
# 120 : tensor(0.0143, grad_fn=<AddBackward0>)
# 121 : tensor(0.0141, grad_fn=<AddBackward0>)
# 122 : tensor(0.0151, grad_fn=<AddBackward0>)
# 123 : tensor(0.0145, grad_fn=<AddBackward0>)
# 124 : tensor(0.0172, grad_fn=<AddBackward0>)
# 125 : tensor(0.0138, grad_fn=<AddBackward0>)
# 126 : tensor(0.0138, grad_fn=<AddBackward0>)
# 127 : tensor(0.0132, grad_fn=<AddBackward0>)
# 128 : tensor(0.0132, grad_fn=<AddBackward0>)
# 129 : tensor(0.0141, grad_fn=<AddBackward0>)
# 130 : tensor(0.0131, grad_fn=<AddBackward0>)
# 131 : tensor(0.0135, grad_fn=<AddBackward0>)
# 132 : tensor(0.0129, grad_fn=<AddBackward0>)
# 133 : tensor(0.0142, grad_fn=<AddBackward0>)
# 134 : tensor(0.0198, grad_fn=<AddBackward0>)
# 135 : tensor(0.0161, grad_fn=<AddBackward0>)
# 136 : tensor(0.0156, grad_fn=<AddBackward0>)
# 137 : tensor(0.0141, grad_fn=<AddBackward0>)
# 138 : tensor(0.0140, grad_fn=<AddBackward0>)
# 139 : tensor(0.0178, grad_fn=<AddBackward0>)
# 140 : tensor(0.0219, grad_fn=<AddBackward0>)
# 141 : tensor(0.0225, grad_fn=<AddBackward0>)
# 142 : tensor(0.0159, grad_fn=<AddBackward0>)
# 143 : tensor(0.0188, grad_fn=<AddBackward0>)
# 144 : tensor(0.0131, grad_fn=<AddBackward0>)
# 145 : tensor(0.0130, grad_fn=<AddBackward0>)
# 146 : tensor(0.0124, grad_fn=<AddBackward0>)
# 147 : tensor(0.0122, grad_fn=<AddBackward0>)
# 148 : tensor(0.0128, grad_fn=<AddBackward0>)
# 149 : tensor(0.0127, grad_fn=<AddBackward0>)
# 150 : tensor(0.0127, grad_fn=<AddBackward0>)
# 151 : tensor(0.0129, grad_fn=<AddBackward0>)
# 152 : tensor(0.0132, grad_fn=<AddBackward0>)
# 153 : tensor(0.0138, grad_fn=<AddBackward0>)
# 154 : tensor(0.0131, grad_fn=<AddBackward0>)
# 155 : tensor(0.0147, grad_fn=<AddBackward0>)
# 156 : tensor(0.0137, grad_fn=<AddBackward0>)
# 157 : tensor(0.0167, grad_fn=<AddBackward0>)
# 158 : tensor(0.0131, grad_fn=<AddBackward0>)
# 159 : tensor(0.0148, grad_fn=<AddBackward0>)
# 160 : tensor(0.0155, grad_fn=<AddBackward0>)
# 161 : tensor(0.0173, grad_fn=<AddBackward0>)
# 162 : tensor(0.0222, grad_fn=<AddBackward0>)
# 163 : tensor(0.0143, grad_fn=<AddBackward0>)
# 164 : tensor(0.0134, grad_fn=<AddBackward0>)
# 165 : tensor(0.0141, grad_fn=<AddBackward0>)
# 166 : tensor(0.0136, grad_fn=<AddBackward0>)
# 167 : tensor(0.0162, grad_fn=<AddBackward0>)
# 168 : tensor(0.0139, grad_fn=<AddBackward0>)
# 169 : tensor(0.0145, grad_fn=<AddBackward0>)
# 170 : tensor(0.0135, grad_fn=<AddBackward0>)
# 171 : tensor(0.0132, grad_fn=<AddBackward0>)
# 172 : tensor(0.0121, grad_fn=<AddBackward0>)
# 173 : tensor(0.0123, grad_fn=<AddBackward0>)
# 174 : tensor(0.0127, grad_fn=<AddBackward0>)
# 175 : tensor(0.0128, grad_fn=<AddBackward0>)
# 176 : tensor(0.0130, grad_fn=<AddBackward0>)
# 177 : tensor(0.0142, grad_fn=<AddBackward0>)
# 178 : tensor(0.0124, grad_fn=<AddBackward0>)
# 179 : tensor(0.0126, grad_fn=<AddBackward0>)
# 180 : tensor(0.0127, grad_fn=<AddBackward0>)
# 181 : tensor(0.0137, grad_fn=<AddBackward0>)
# 182 : tensor(0.0141, grad_fn=<AddBackward0>)
# 183 : tensor(0.0146, grad_fn=<AddBackward0>)
# 184 : tensor(0.0131, grad_fn=<AddBackward0>)
# 185 : tensor(0.0130, grad_fn=<AddBackward0>)
# 186 : tensor(0.0122, grad_fn=<AddBackward0>)
# 187 : tensor(0.0124, grad_fn=<AddBackward0>)
# 188 : tensor(0.0120, grad_fn=<AddBackward0>)
# 189 : tensor(0.0130, grad_fn=<AddBackward0>)
# 190 : tensor(0.0134, grad_fn=<AddBackward0>)
# 191 : tensor(0.0146, grad_fn=<AddBackward0>)
# 192 : tensor(0.0152, grad_fn=<AddBackward0>)
# 193 : tensor(0.0172, grad_fn=<AddBackward0>)
# 194 : tensor(0.0146, grad_fn=<AddBackward0>)
# 195 : tensor(0.0127, grad_fn=<AddBackward0>)
# 196 : tensor(0.0119, grad_fn=<AddBackward0>)
# 197 : tensor(0.0129, grad_fn=<AddBackward0>)
# 198 : tensor(0.0134, grad_fn=<AddBackward0>)
# 199 : tensor(0.0144, grad_fn=<AddBackward0>)
# 200 : tensor(0.0133, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.4665)
# mse test 0.70009154
# mse train 0.24139048
# 1 : tensor(0.1115, grad_fn=<AddBackward0>)
# 2 : tensor(0.0741, grad_fn=<AddBackward0>)
# 3 : tensor(0.0515, grad_fn=<AddBackward0>)
# 4 : tensor(0.0431, grad_fn=<AddBackward0>)
# 5 : tensor(0.0442, grad_fn=<AddBackward0>)
# 6 : tensor(0.0461, grad_fn=<AddBackward0>)
# 7 : tensor(0.0469, grad_fn=<AddBackward0>)
# 8 : tensor(0.0465, grad_fn=<AddBackward0>)
# 9 : tensor(0.0446, grad_fn=<AddBackward0>)
# 10 : tensor(0.0447, grad_fn=<AddBackward0>)
# 11 : tensor(0.0436, grad_fn=<AddBackward0>)
# 12 : tensor(0.0434, grad_fn=<AddBackward0>)
# 13 : tensor(0.0427, grad_fn=<AddBackward0>)
# 14 : tensor(0.0421, grad_fn=<AddBackward0>)
# 15 : tensor(0.0403, grad_fn=<AddBackward0>)
# 16 : tensor(0.0374, grad_fn=<AddBackward0>)
# 17 : tensor(0.0336, grad_fn=<AddBackward0>)
# 18 : tensor(0.0291, grad_fn=<AddBackward0>)
# 19 : tensor(0.0268, grad_fn=<AddBackward0>)
# 20 : tensor(0.0266, grad_fn=<AddBackward0>)
# 21 : tensor(0.0260, grad_fn=<AddBackward0>)
# 22 : tensor(0.0263, grad_fn=<AddBackward0>)
# 23 : tensor(0.0242, grad_fn=<AddBackward0>)
# 24 : tensor(0.0246, grad_fn=<AddBackward0>)
# 25 : tensor(0.0234, grad_fn=<AddBackward0>)
# 26 : tensor(0.0239, grad_fn=<AddBackward0>)
# 27 : tensor(0.0228, grad_fn=<AddBackward0>)
# 28 : tensor(0.0226, grad_fn=<AddBackward0>)
# 29 : tensor(0.0218, grad_fn=<AddBackward0>)
# 30 : tensor(0.0215, grad_fn=<AddBackward0>)
# 31 : tensor(0.0214, grad_fn=<AddBackward0>)
# 32 : tensor(0.0204, grad_fn=<AddBackward0>)
# 33 : tensor(0.0219, grad_fn=<AddBackward0>)
# 34 : tensor(0.0196, grad_fn=<AddBackward0>)
# 35 : tensor(0.0217, grad_fn=<AddBackward0>)
# 36 : tensor(0.0192, grad_fn=<AddBackward0>)
# 37 : tensor(0.0198, grad_fn=<AddBackward0>)
# 38 : tensor(0.0208, grad_fn=<AddBackward0>)
# 39 : tensor(0.0209, grad_fn=<AddBackward0>)
# 40 : tensor(0.0189, grad_fn=<AddBackward0>)
# 41 : tensor(0.0223, grad_fn=<AddBackward0>)
# 42 : tensor(0.0196, grad_fn=<AddBackward0>)
# 43 : tensor(0.0277, grad_fn=<AddBackward0>)
# 44 : tensor(0.0192, grad_fn=<AddBackward0>)
# 45 : tensor(0.0209, grad_fn=<AddBackward0>)
# 46 : tensor(0.0194, grad_fn=<AddBackward0>)
# 47 : tensor(0.0205, grad_fn=<AddBackward0>)
# 48 : tensor(0.0202, grad_fn=<AddBackward0>)
# 49 : tensor(0.0187, grad_fn=<AddBackward0>)
# 50 : tensor(0.0189, grad_fn=<AddBackward0>)
# 51 : tensor(0.0186, grad_fn=<AddBackward0>)
# 52 : tensor(0.0186, grad_fn=<AddBackward0>)
# 53 : tensor(0.0182, grad_fn=<AddBackward0>)
# 54 : tensor(0.0187, grad_fn=<AddBackward0>)
# 55 : tensor(0.0184, grad_fn=<AddBackward0>)
# 56 : tensor(0.0189, grad_fn=<AddBackward0>)
# 57 : tensor(0.0187, grad_fn=<AddBackward0>)
# 58 : tensor(0.0190, grad_fn=<AddBackward0>)
# 59 : tensor(0.0193, grad_fn=<AddBackward0>)
# 60 : tensor(0.0200, grad_fn=<AddBackward0>)
# 61 : tensor(0.0199, grad_fn=<AddBackward0>)
# 62 : tensor(0.0334, grad_fn=<AddBackward0>)
# 63 : tensor(0.0203, grad_fn=<AddBackward0>)
# 64 : tensor(0.0214, grad_fn=<AddBackward0>)
# 65 : tensor(0.0259, grad_fn=<AddBackward0>)
# 66 : tensor(0.0207, grad_fn=<AddBackward0>)
# 67 : tensor(0.0195, grad_fn=<AddBackward0>)
# 68 : tensor(0.0196, grad_fn=<AddBackward0>)
# 69 : tensor(0.0191, grad_fn=<AddBackward0>)
# 70 : tensor(0.0195, grad_fn=<AddBackward0>)
# 71 : tensor(0.0184, grad_fn=<AddBackward0>)
# 72 : tensor(0.0184, grad_fn=<AddBackward0>)
# 73 : tensor(0.0191, grad_fn=<AddBackward0>)
# 74 : tensor(0.0181, grad_fn=<AddBackward0>)
# 75 : tensor(0.0181, grad_fn=<AddBackward0>)
# 76 : tensor(0.0190, grad_fn=<AddBackward0>)
# 77 : tensor(0.0186, grad_fn=<AddBackward0>)
# 78 : tensor(0.0207, grad_fn=<AddBackward0>)
# 79 : tensor(0.0269, grad_fn=<AddBackward0>)
# 80 : tensor(0.0217, grad_fn=<AddBackward0>)
# 81 : tensor(0.0204, grad_fn=<AddBackward0>)
# 82 : tensor(0.0187, grad_fn=<AddBackward0>)
# 83 : tensor(0.0180, grad_fn=<AddBackward0>)
# 84 : tensor(0.0180, grad_fn=<AddBackward0>)
# 85 : tensor(0.0176, grad_fn=<AddBackward0>)
# 86 : tensor(0.0185, grad_fn=<AddBackward0>)
# 87 : tensor(0.0175, grad_fn=<AddBackward0>)
# 88 : tensor(0.0176, grad_fn=<AddBackward0>)
# 89 : tensor(0.0174, grad_fn=<AddBackward0>)
# 90 : tensor(0.0167, grad_fn=<AddBackward0>)
# 91 : tensor(0.0171, grad_fn=<AddBackward0>)
# 92 : tensor(0.0169, grad_fn=<AddBackward0>)
# 93 : tensor(0.0171, grad_fn=<AddBackward0>)
# 94 : tensor(0.0176, grad_fn=<AddBackward0>)
# 95 : tensor(0.0168, grad_fn=<AddBackward0>)
# 96 : tensor(0.0167, grad_fn=<AddBackward0>)
# 97 : tensor(0.0171, grad_fn=<AddBackward0>)
# 98 : tensor(0.0164, grad_fn=<AddBackward0>)
# 99 : tensor(0.0181, grad_fn=<AddBackward0>)
# 100 : tensor(0.0175, grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.4457)
# 101 : tensor(0.0181, grad_fn=<AddBackward0>)
# 102 : tensor(0.0207, grad_fn=<AddBackward0>)
# 103 : tensor(0.0185, grad_fn=<AddBackward0>)
# 104 : tensor(0.0204, grad_fn=<AddBackward0>)
# 105 : tensor(0.0180, grad_fn=<AddBackward0>)
# 106 : tensor(0.0168, grad_fn=<AddBackward0>)
# 107 : tensor(0.0183, grad_fn=<AddBackward0>)
# 108 : tensor(0.0179, grad_fn=<AddBackward0>)
# 109 : tensor(0.0197, grad_fn=<AddBackward0>)
# 110 : tensor(0.0197, grad_fn=<AddBackward0>)
# 111 : tensor(0.0194, grad_fn=<AddBackward0>)
# 112 : tensor(0.0172, grad_fn=<AddBackward0>)
# 113 : tensor(0.0166, grad_fn=<AddBackward0>)
# 114 : tensor(0.0158, grad_fn=<AddBackward0>)
# 115 : tensor(0.0159, grad_fn=<AddBackward0>)
# 116 : tensor(0.0158, grad_fn=<AddBackward0>)
# 117 : tensor(0.0160, grad_fn=<AddBackward0>)
# 118 : tensor(0.0167, grad_fn=<AddBackward0>)
# 119 : tensor(0.0163, grad_fn=<AddBackward0>)
# 120 : tensor(0.0197, grad_fn=<AddBackward0>)
# 121 : tensor(0.0166, grad_fn=<AddBackward0>)
# 122 : tensor(0.0185, grad_fn=<AddBackward0>)
# 123 : tensor(0.0158, grad_fn=<AddBackward0>)
# 124 : tensor(0.0157, grad_fn=<AddBackward0>)
# 125 : tensor(0.0163, grad_fn=<AddBackward0>)
# 126 : tensor(0.0157, grad_fn=<AddBackward0>)
# 127 : tensor(0.0151, grad_fn=<AddBackward0>)
# 128 : tensor(0.0174, grad_fn=<AddBackward0>)
# 129 : tensor(0.0146, grad_fn=<AddBackward0>)
# 130 : tensor(0.0160, grad_fn=<AddBackward0>)
# 131 : tensor(0.0151, grad_fn=<AddBackward0>)
# 132 : tensor(0.0146, grad_fn=<AddBackward0>)
# 133 : tensor(0.0150, grad_fn=<AddBackward0>)
# 134 : tensor(0.0147, grad_fn=<AddBackward0>)
# 135 : tensor(0.0155, grad_fn=<AddBackward0>)
# 136 : tensor(0.0157, grad_fn=<AddBackward0>)
# 137 : tensor(0.0151, grad_fn=<AddBackward0>)
# 138 : tensor(0.0191, grad_fn=<AddBackward0>)
# 139 : tensor(0.0147, grad_fn=<AddBackward0>)
# 140 : tensor(0.0191, grad_fn=<AddBackward0>)
# 141 : tensor(0.0148, grad_fn=<AddBackward0>)
# 142 : tensor(0.0189, grad_fn=<AddBackward0>)
# 143 : tensor(0.0144, grad_fn=<AddBackward0>)
# 144 : tensor(0.0151, grad_fn=<AddBackward0>)
# 145 : tensor(0.0140, grad_fn=<AddBackward0>)
# 146 : tensor(0.0141, grad_fn=<AddBackward0>)
# 147 : tensor(0.0146, grad_fn=<AddBackward0>)
# 148 : tensor(0.0141, grad_fn=<AddBackward0>)
# 149 : tensor(0.0144, grad_fn=<AddBackward0>)
# 150 : tensor(0.0145, grad_fn=<AddBackward0>)
# 151 : tensor(0.0139, grad_fn=<AddBackward0>)
# 152 : tensor(0.0146, grad_fn=<AddBackward0>)
# 153 : tensor(0.0153, grad_fn=<AddBackward0>)
# 154 : tensor(0.0134, grad_fn=<AddBackward0>)
# 155 : tensor(0.0178, grad_fn=<AddBackward0>)
# 156 : tensor(0.0140, grad_fn=<AddBackward0>)
# 157 : tensor(0.0180, grad_fn=<AddBackward0>)
# 158 : tensor(0.0135, grad_fn=<AddBackward0>)
# 159 : tensor(0.0148, grad_fn=<AddBackward0>)
# 160 : tensor(0.0131, grad_fn=<AddBackward0>)
# 161 : tensor(0.0137, grad_fn=<AddBackward0>)
# 162 : tensor(0.0129, grad_fn=<AddBackward0>)
# 163 : tensor(0.0135, grad_fn=<AddBackward0>)
# 164 : tensor(0.0131, grad_fn=<AddBackward0>)
# 165 : tensor(0.0134, grad_fn=<AddBackward0>)
# 166 : tensor(0.0135, grad_fn=<AddBackward0>)
# 167 : tensor(0.0144, grad_fn=<AddBackward0>)
# 168 : tensor(0.0144, grad_fn=<AddBackward0>)
# 169 : tensor(0.0185, grad_fn=<AddBackward0>)
# 170 : tensor(0.0154, grad_fn=<AddBackward0>)
# 171 : tensor(0.0183, grad_fn=<AddBackward0>)
# 172 : tensor(0.0136, grad_fn=<AddBackward0>)
# 173 : tensor(0.0142, grad_fn=<AddBackward0>)
# 174 : tensor(0.0135, grad_fn=<AddBackward0>)
# 175 : tensor(0.0225, grad_fn=<AddBackward0>)
# 176 : tensor(0.0132, grad_fn=<AddBackward0>)
# 177 : tensor(0.0154, grad_fn=<AddBackward0>)
# 178 : tensor(0.0130, grad_fn=<AddBackward0>)
# 179 : tensor(0.0131, grad_fn=<AddBackward0>)
# 180 : tensor(0.0126, grad_fn=<AddBackward0>)
# 181 : tensor(0.0144, grad_fn=<AddBackward0>)
# 182 : tensor(0.0125, grad_fn=<AddBackward0>)
# 183 : tensor(0.0131, grad_fn=<AddBackward0>)
# 184 : tensor(0.0127, grad_fn=<AddBackward0>)
# 185 : tensor(0.0129, grad_fn=<AddBackward0>)
# 186 : tensor(0.0128, grad_fn=<AddBackward0>)
# 187 : tensor(0.0144, grad_fn=<AddBackward0>)
# 188 : tensor(0.0130, grad_fn=<AddBackward0>)
# 189 : tensor(0.0188, grad_fn=<AddBackward0>)
# 190 : tensor(0.0131, grad_fn=<AddBackward0>)
# 191 : tensor(0.0159, grad_fn=<AddBackward0>)
# 192 : tensor(0.0130, grad_fn=<AddBackward0>)
# 193 : tensor(0.0130, grad_fn=<AddBackward0>)
# 194 : tensor(0.0127, grad_fn=<AddBackward0>)
# 195 : tensor(0.0128, grad_fn=<AddBackward0>)
# 196 : tensor(0.0125, grad_fn=<AddBackward0>)
# 197 : tensor(0.0131, grad_fn=<AddBackward0>)
# 198 : tensor(0.0132, grad_fn=<AddBackward0>)
# 199 : tensor(0.0134, grad_fn=<AddBackward0>)
# 200 : tensor(0.0132, grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.4725)
# mse test 0.95626324
# mse train 0.29793867

# %% [markdown]
# ## Loading in and Plotting the data

# %%
n_trials = 25

# %%
####### MSE
#HIGH
train_mse_high = []
test_mse_high = []
for k in range(1,26):
    neuron_loc = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/neuron_loc_{k}.npy'))

    test_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_recon_{k}.npy'))
    test_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_gt_{k}.npy'))
    
    train_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_recon_{k}.npy'))
    train_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_gt_{k}.npy'))
    train_mse = np.linalg.norm(train_recon - train_gt) / np.linalg.norm(train_gt)

    mask = np.ones(test_gt.shape[1], dtype=bool)
    mask[neuron_loc] = False
    test_ex = test_recon.T[mask]
    test_gt_ex = test_gt.T[mask]
    mask = np.ones(train_gt.shape[1], dtype=bool)
    mask[neuron_loc] = False
    train_ex = train_recon.T[mask]
    train_gt_ex = train_gt.T[mask]

    test_mse = np.linalg.norm(test_ex - test_gt_ex) / np.linalg.norm(test_gt_ex)
    train_mse = np.linalg.norm(train_ex - train_gt_ex) / np.linalg.norm(train_gt_ex)

    train_mse_high.append(train_mse)
    test_mse_high.append(test_mse)


#LOW
train_mse_low = []
test_mse_low = []
for k in range(1,26):
    neuron_loc = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/neuron_loc_{k}.npy'))

    test_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/test_recon_{k}.npy'))
    test_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/test_gt_{k}.npy'))
    
    train_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/train_recon_{k}.npy'))
    train_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/train_gt_{k}.npy'))
    train_mse = np.linalg.norm(train_recon - train_gt) / np.linalg.norm(train_gt)

    mask = np.ones(test_gt.shape[0], dtype=bool)
    mask[neuron_loc] = False
    test_ex = test_recon[mask]
    test_gt_ex = test_gt[mask]
    mask = np.ones(train_gt.shape[0], dtype=bool)
    mask[neuron_loc] = False
    train_ex = train_recon[mask]
    train_gt_ex = train_gt[mask]

    test_mse = np.linalg.norm(test_ex - test_gt_ex) / np.linalg.norm(test_gt_ex)
    train_mse = np.linalg.norm(train_ex - train_gt_ex) / np.linalg.norm(train_gt_ex)

    train_mse_low.append(train_mse)
    test_mse_low.append(test_mse)

#RANDOM
train_mse_rand = []
test_mse_rand = []
for k in range(1,26):
    neuron_loc = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/neuron_loc_{k}.npy'))

    test_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/test_recon_{k}.npy'))
    test_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/test_gt_{k}.npy'))
    
    train_recon = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/train_recon_{k}.npy'))
    train_gt = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/train_gt_{k}.npy'))
    train_mse = np.linalg.norm(train_recon - train_gt) / np.linalg.norm(train_gt)

    mask = np.ones(test_gt.shape[0], dtype=bool)
    mask[neuron_loc] = False
    test_ex = test_recon[mask]
    test_gt_ex = test_gt[mask]
    mask = np.ones(train_gt.shape[0], dtype=bool)
    mask[neuron_loc] = False
    train_ex = train_recon[mask]
    train_gt_ex = train_gt[mask]

    test_mse = np.linalg.norm(test_ex - test_gt_ex) / np.linalg.norm(test_gt_ex)
    train_mse = np.linalg.norm(train_ex - train_gt_ex) / np.linalg.norm(train_gt_ex)

    train_mse_rand.append(train_mse)
    test_mse_rand.append(test_mse)

# %%
######## Ground truth
train_gt = []
test_gt = []

for k in range(1,26):
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_gt_{k}.npy'))
    train_gt.append(data)
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_gt_{k}.npy'))
    test_gt.append(data)

# %%
######## Neurons
# HIGH
neuron_high = []
# LOW
neuron_low = []
# RANDOM
neuron_rand = []


for k in range(1,26):
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/neuron_loc_{k}.npy'))
    neuron_high.append(data)

    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/neuron_loc_{k}.npy'))
    neuron_low.append(data)

    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/neuron_loc_{k}.npy'))
    neuron_rand.append(data)

# %%
######## Reconstruction
# HIGH
train_recon_high = []
test_recon_high = []

# LOW
train_recon_low = []
test_recon_low = []

# RANDOM
train_recon_rand = []
test_recon_rand = []



for k in range(1,26):
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/train_recon_{k}.npy'))
    train_recon_high.append(data)
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/high/test_recon_{k}.npy'))
    test_recon_high.append(data)

    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/train_recon_{k}.npy'))
    train_recon_low.append(data)
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/low/test_recon_{k}.npy'))
    test_recon_low.append(data)

    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/train_recon_{k}.npy'))
    train_recon_rand.append(data)
    data = np.load(os.path.join(HOME_DIR, f'worms/data_output/exp_Aiii_pt1/rand/test_recon_{k}.npy'))
    test_recon_rand.append(data)


## Calculating the average and standard deviation
# HIGH
train_ave_high = []
test_ave_high = []
train_std_high = []
test_std_high = []

# LOW
train_ave_low = []
test_ave_low = []
train_std_low = []
test_std_low = []

# RANDOM
train_ave_rand = []
test_ave_rand = []
train_std_rand = []
test_std_rand = []


for k in range(n):
    train_ave_h = np.zeros((n_trials, train_recon_high[0].shape[0]))
    train_ave_l = np.zeros((n_trials, train_recon_high[0].shape[0]))
    train_ave_r = np.zeros((n_trials, train_recon_high[0].shape[0]))

    test_ave_h = np.zeros((n_trials, test_recon_high[0].shape[0]))
    test_ave_l = np.zeros((n_trials, test_recon_high[0].shape[0]))
    test_ave_r = np.zeros((n_trials, test_recon_high[0].shape[0]))

    for i in range(n_trials):
        train_ave_h[i,:] = train_recon_high[i][:,k]
        train_ave_l[i,:] = train_recon_low[i][:,k]
        train_ave_r[i,:] = train_recon_rand[i][:,k]

        test_ave_h[i,:] = test_recon_high[i][:,k]
        test_ave_l[i,:] = test_recon_low[i][:,k]
        test_ave_r[i,:] = test_recon_rand[i][:,k]

    train_ave_high.append(np.mean(train_ave_h, axis = 0))
    train_std_high.append(np.std(train_ave_h, axis = 0))
    test_ave_high.append(np.mean(test_ave_h, axis = 0))
    test_std_high.append(np.std(test_ave_h, axis = 0))
    
    train_ave_low.append(np.mean(train_ave_l, axis = 0))
    train_std_low.append(np.std(train_ave_l, axis = 0))
    test_ave_low.append(np.mean(test_ave_l, axis = 0))
    test_std_low.append(np.std(test_ave_l, axis = 0))

    train_ave_rand.append(np.mean(train_ave_r, axis = 0))
    train_std_rand.append(np.std(train_ave_r, axis = 0))
    test_ave_rand.append(np.mean(test_ave_r, axis = 0))
    test_std_rand.append(np.std(test_ave_r, axis = 0))

# %%
x = np.arange(n_trials)
fig, ax = plt.subplots(1,2, figsize = (6,2.5))
ax[0].scatter(x, train_mse_high, color = 'red', label = 'High Variance', marker = 'o')
ax[0].scatter(x, train_mse_low, color = 'darkblue', label = 'Low Variance', marker = 's')
ax[0].scatter(x, train_mse_rand, color = 'darkgreen', label = 'Random', marker = '^')
# ax[0].set_title('Training MSE')
ax[0].set_ylim([0,1.2])
ax[0].set_ylabel('MSE', fontsize = 12)
ax[0].set_xlabel('Trial', fontsize = 12)



ax[1].scatter(x, test_mse_high, color = 'red', label = 'High Variance', marker = 'o')
ax[1].scatter(x, test_mse_low, color = 'darkblue', label = 'Low Variance', marker = 's')
ax[1].scatter(x, test_mse_rand, color = 'darkgreen', label = 'Random', marker = '^')
ax[1].set_ylim([0,1.2])
ax[1].set_ylabel('MSE', fontsize = 12)
ax[1].set_xlabel('Trial', fontsize = 12)


# ax[1].set_title('Testing MSE')


ax[0].legend()
plt.tight_layout()
plt.savefig(os.path.join(HOME_DIR, f'worms/data_output/figs/mse_var_scatter.png'), transparent=True, dpi=500)

# %%
means_high = [np.mean(train_mse_high), np.mean(test_mse_high) ]
means_low = [np.mean(train_mse_low), np.mean(test_mse_low)]
means_rand = [np.mean(train_mse_rand), np.mean(test_mse_rand)]


std_high = [np.std(train_mse_high)/5, np.std(test_mse_high)/5 ]
std_low = [np.std(train_mse_low)/5, np.std(test_mse_low)/5]
std_rand = [np.std(train_mse_rand)/5, np.std(test_mse_rand)/5]


x = np.arange(len(means_high))
labels = ['Train', 'Test']

fig, ax = plt.subplots(figsize = (6,2.5))

ax.bar(x-0.3, means_high, yerr=std_high, capsize=5, width = 0.25,
              edgecolor='maroon', facecolor='indianred', linewidth=2, hatch = '//')
ax.bar(x,     means_low, yerr=std_low, capsize=5, width = 0.25,
              edgecolor='navy', facecolor='cornflowerblue', linewidth=2, hatch = '//')
ax.bar(x+0.3, means_rand, yerr=std_rand, capsize=5, width = 0.25,
              edgecolor='darkgreen', facecolor='darkseagreen', linewidth=2, hatch = 'x')


# Customize ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize = 15)
ax.set_ylabel("MSE", fontsize = 15)
ax.tick_params(axis='y', labelsize=12)
ax.legend(['High', 'Low', 'Rand'],loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)

plt.tight_layout()
plt.savefig(os.path.join(HOME_DIR, f'worms/data_output/figs/mse_bar.png'), transparent=True, dpi=500)

plt.show()

# %%
n_loc = 45

# %%
## Plotting ave and std TEST
#HIGH
fig, ax = plt.subplots(1, figsize = (5,4))
plt.plot(test_gt[0][:,n_loc], color = 'grey', alpha = 0.6)
plt.plot(test_ave_high[n_loc], color = 'black')
plt.ylim([-0.1,1.3])

high = test_ave_high[n_loc] + test_std_high[n_loc]
low = test_ave_high[n_loc] - test_std_high[n_loc]
plt.fill_between(np.arange(test_std_high[0].shape[0]), low, high, color = 'red', alpha =0.7)
plt.show()

# LOW
fig, ax = plt.subplots(1, figsize = (5,4))
plt.plot(test_gt[0][:,n_loc], color = 'grey', alpha = 0.6)
plt.plot(test_ave_low[n_loc], color = 'black')
plt.ylim([-0.1,1.3])

high = test_ave_low[n_loc] + test_std_low[n_loc]
low = test_ave_low[n_loc] - test_std_low[n_loc]
plt.fill_between(np.arange(test_std_low[0].shape[0]), low, high, color = 'blue', alpha =0.7)
plt.show()

#RAND
fig, ax = plt.subplots(1, figsize = (5,4))
plt.plot(test_gt[0][:,n_loc], color = 'grey', alpha = 0.6)
plt.plot(test_ave_rand[n_loc], color = 'black')
plt.ylim([-0.1,1.3])

high = test_ave_rand[n_loc] + test_std_high[n_loc]
low = test_ave_rand[n_loc] - test_std_high[n_loc]
plt.fill_between(np.arange(test_std_rand[0].shape[0]), low, high, color = 'green', alpha =0.7)
plt.show()

# %%
### Plotting reconstructions carpet plots-- Training Dataset

### Reconstructed and ground truth Carpet Plot
fig, axes = plt.subplots(2, figsize=(6, 4), sharex=True, sharey=True)
# Plot the reconstructed data
axes[0].imshow(train_recon_high[10].T, aspect='auto')
axes[0].set_title("Reconstructed Data")
# Plot the ground truth data
axes[1].imshow(train_gt[10].T, aspect='auto')
axes[1].set_title("Ground Truth Data")
axes[1].set_xlabel('Time')
axes[1].set_ylabel('Neurons')

plt.tight_layout()
plt.show()


### Plotting reconstructions carpet plots-- Testing Dataset

### Reconstructed and ground truth Carpet Plot
fig, axes = plt.subplots(2, figsize=(6, 4), sharex=True, sharey=True)
# Plot the reconstructed data
axes[0].imshow(test_recon_high[10].T, aspect='auto')
axes[0].set_title("Reconstructed Data")
# Plot the ground truth data
axes[1].imshow(test_gt[10].T, aspect='auto')
axes[1].set_title("Ground Truth Data")
axes[1].set_xlabel('Time')
axes[1].set_ylabel('Neurons')

plt.tight_layout()
plt.show()
