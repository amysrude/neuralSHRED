# %% [markdown]
# # Applying SHRED to the Mice Dataset

# %% [markdown]
# Dataset obtained from Allen Barain Atlas https://allensdk.readthedocs.io/en/latest/visual_coding_neuropixels.html

# %% [markdown]
# SHRED (SHallow REcurrent Decoder) models are a network architecture that merges a recurrent layer (LSTM) with a shallow decoder network (SDN) to reconstruct high-dimensional spatio-temporal fields from a trajectory of sensor measurements of the field. More formally, the SHRED architecture can be written as
# $$ \mathcal {H} \left( \{ y_i \} _{i=t-k}^t \right) = \mathcal {F} \left( \mathcal {G} \left( \{ y_i \} _{i=t-k}^t \right) ; W_{RN}) ; W_{SD} \right)$$
# where $\mathcal F$ is a feed forward network parameterized by weights $W_{SD}$, $\mathcal G$ is a LSTM network parameterized by weights $W_{RN}$, and $\{ y_i \} _{i=t-k}^t$ is a trajectory of sensor measurements of a high-dimensional spatio-temporal field $\{ x_i \} _{i=t-k}^t$.

# %% [markdown]
# Goal: Reconstruct LFP potential from single unit recordings
#
# Spike band:
# - ~30 kHz sample rate
# - 500 Hz analog hi-pass
# - 150 Hz digital hi-pass
#
#
# LFP band:
# - ~2.5 kHz original sample rate
# - 1000 Hz analog lo-pass
# - 625 Hz digital lo-pass
# - NWB includes every 2nd sample and every 4th channel

# %%
# Importing all dependencies 
import numpy as np
import numpy as np
import torch
import subprocess
import os
import torch
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import random
import mne
from scipy.signal import butter, filtfilt
from scipy.signal import welch
from scipy.interpolate import CubicSpline
from scipy.io import loadmat
from sklearn.linear_model import Ridge
from scipy.ndimage import gaussian_filter1d

# %%
import xarray as xr
import pandas as pd
from scipy.ndimage import gaussian_filter
from pathlib import Path
import json
from IPython.display import display
from PIL import Image

from allensdk.brain_observatory.ecephys.visualization import plot_mean_waveforms, plot_spike_counts, raster_plot
from allensdk.brain_observatory.visualization import plot_running_speed

# tell pandas to show all columns when we display a DataFrame
pd.set_option("display.max_columns", None)

# %%
#Set up data cache
from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache

data_directory = "/home/amy/SHRED_neuro/mice/data" #where data will be stored
manifest_path = os.path.join(data_directory, 'manifest.json')
cache = EcephysProjectCache.from_warehouse(manifest = manifest_path)

# %%
sessions = cache.get_session_table()

print('Total number of sessions: ' + str(len(sessions)))

sessions.head()


# Can also filter which mice to select
filtered_sessions = sessions[(sessions.index == 756029989)]

filtered_sessions.head()
# Out:
# Total number of sessions: 58
#                    published_at  specimen_id           session_type  \
# id
# 756029989  2019-10-03T00:00:00Z    734865738  brain_observatory_1.1
#
#            age_in_days sex                                  full_genotype  \
# id
# 756029989         96.0   M  Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 756029989         684           2214            6
#
#                                   ecephys_structure_acronyms
# id
# 756029989  [TH, DG, CA3, CA1, VISl, nan, PO, Eth, LP, VIS...

# %%
#Loading dataset for specific session
session_id = 756029989 # for example
session = cache.get_session_data(session_id)

print([attr_or_method for attr_or_method in dir(session) if attr_or_method[0] != '_'])
# Out:
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# ['DETAILED_STIMULUS_PARAMETERS', 'LazyProperty', 'age_in_days', 'api', 'channel_structure_intervals', 'channels', 'conditionwise_spike_statistics', 'ecephys_session_id', 'from_nwb_path', 'full_genotype', 'get_current_source_density', 'get_inter_presentation_intervals_for_stimulus', 'get_invalid_times', 'get_lfp', 'get_parameter_values_for_stimulus', 'get_pupil_data', 'get_screen_gaze_data', 'get_stimulus_epochs', 'get_stimulus_parameter_values', 'get_stimulus_table', 'inter_presentation_intervals', 'invalid_times', 'mean_waveforms', 'metadata', 'num_channels', 'num_probes', 'num_stimulus_presentations', 'num_units', 'optogenetic_stimulation_epochs', 'presentationwise_spike_counts', 'presentationwise_spike_times', 'probes', 'rig_equipment_name', 'rig_geometry_data', 'running_speed', 'session_start_time', 'session_type', 'sex', 'specimen_name', 'spike_amplitudes', 'spike_times', 'stimulus_conditions', 'stimulus_names', 'stimulus_presentations', 'structure_acronyms', 'structurewise_unit_counts', 'units']

# %% [markdown]
# **Finding well-isolated, high-firing rate unit from the visual cortex and the associated LFP**

# %%
probe_id = session.probes.index.values[0]

units_of_interest = session.units[(session.units.probe_id == probe_id) &
                                  (session.units.ecephys_structure_acronym.str.find('VIS') > -1) &
                                  (session.units.firing_rate > 10) & 
                                  (session.units.nn_hit_rate > 0.95)]
                                  
len(units_of_interest)
# Out:
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# 20

# %%
unit_id = units_of_interest.index.values[0]

channel_index = units_of_interest.loc[unit_id].probe_channel_number
print(unit_id)
print(channel_index)
# Out:
# 951816951
# 211

# %%
channel_id = session.channels[(session.channels.probe_channel_number == channel_index) & 
                                     (session.channels.probe_id == probe_id)].index.values[0]
channel_id
# Out:
# 850126796

# %%
# list the probes recorded from in this session
session.probes.head()
# Out:
#           description                 location  sampling_rate  \
# id
# 760640083      probeA  See electrode locations   29999.949611
# 760640087      probeB  See electrode locations   29999.902541
# 760640090      probeC  See electrode locations   29999.905275
# 760640094      probeD  See electrode locations   29999.905275
# 760640097      probeE  See electrode locations   29999.985335
#
#            lfp_sampling_rate  has_lfp_data
# id
# 760640083        1249.997900          True
# 760640087        1249.995939          True
# 760640090        1249.996053          True
# 760640094        1249.996053          True
# 760640097        1249.999389          True

# %%
{session.probes.loc[probe_id].description : 
     list(session.channels[session.channels.probe_id == probe_id].ecephys_structure_acronym.unique())
     for probe_id in session.probes.index.values}
# Out:
# {'probeA': [nan, 'APN', 'DG', 'CA1', 'VISam'],
#  'probeB': ['VISpm', nan, 'LP', 'DG', 'CA1', 'PO', 'Eth'],
#  'probeC': ['VISp', nan, 'POL', 'APN', 'MB', 'SCig', 'POST', 'SUB'],
#  'probeD': ['VISl', nan, 'TH', 'DG', 'CA3', 'CA1'],
#  'probeE': [nan, 'VPM', 'TH', 'LGd', 'CA3', 'CA2', 'CA1', 'VISal'],
#  'probeF': [nan, 'DG', 'CA1', 'VISrl']}

# %%
lfp = session.get_lfp(probe_id)
# Out:
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %%
print(lfp)
# Out:
# <xarray.DataArray 'LFP' (time: 12453025, channel: 87)>
# array([[ 1.18950002e-05,  2.73000005e-05,  9.16499994e-06, ...,
#          0.00000000e+00,  2.73000001e-06,  3.89999997e-07],
#        [ 9.41850012e-05,  8.95049961e-05,  1.22849997e-05, ...,
#          5.84999998e-06,  5.84999998e-06, -1.15049997e-05],
#        [ 6.04499983e-05,  5.79150001e-05,  1.48199997e-05, ...,
#          0.00000000e+00,  3.90000014e-06, -1.44300002e-05],
#        ...,
#        [ 1.05299996e-05,  5.12849983e-05,  8.32649966e-05, ...,
#          0.00000000e+00, -3.80249985e-05, -2.16449989e-05],
#        [-1.36500000e-06,  3.56849996e-05,  5.46000010e-05, ...,
#          0.00000000e+00, -2.84700000e-05, -2.43750001e-05],
#        [-1.01400001e-05,  1.46249995e-05,  3.56849996e-05, ...,
#          2.73000001e-06, -1.26750001e-05, -9.55500036e-06]], dtype=float32)
# Coordinates:
#   * time     (time) float64 3.774 3.775 3.776 ... 9.966e+03 9.966e+03 9.966e+03
#   * channel  (channel) int64 850126378 850126386 ... 850127058 850127066

# %%
start_time = 1585.734418
end_time = 1587.736098

spike_times = session.spike_times[unit_id]

times_in_range = spike_times[(spike_times > start_time) & (spike_times < end_time)]

lfp_data = lfp.sel(time = slice(start_time, end_time))
lfp_data = lfp_data.sel(channel = channel_id, method='nearest')
# Out:
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/allensdk/brain_observatory/ecephys/ecephys_session.py:1371: UserWarning: Session includes invalid time intervals that could be accessed with the attribute 'invalid_times',Spikes within these intervals are invalid and may need to be excluded from the analysis.
#   warnings.warn("Session includes invalid time intervals that could "
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/amy/SHRED_neuro/neuroenv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.2 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %%
plt.plot(lfp_data.time - np.ones(lfp_data.time.shape)*1585.734418, lfp_data)
plt.plot(times_in_range- np.ones(times_in_range.shape)*1585.734418, np.ones(times_in_range.shape)*6e-4, '.r')
plt.xlabel('Stimulus Time (s)')
plt.ylabel('LFP (V)')
# Out:
# Text(0, 0.5, 'LFP (V)')

# %%
### Converting to numpy arrays
time = lfp_data.time.values - np.ones(lfp_data.time.shape)*1585.734418
lfp_array = lfp_data.values

target_arr = np.round(lfp_data.time, decimals = 3)
query_vals = np.round(times_in_range, decimals = 3)

indices = [np.where(target_arr == val)[0][0] for val in query_vals]
unit_array = np.zeros((lfp_array.shape))
unit_array[indices] = 1

ones_indices = np.where(unit_array == 1)[0]
plt.eventplot(time[ones_indices], lineoffsets=0.0008, linelengths=0.00006, color = 'purple')  # spike train style
plt.plot(time , lfp_array)

# plt.plot(time, unit_array*0.0004, '.r')
plt.xlabel('Stimulus Time (s)')
plt.ylabel('LFP (V)')
# Out:
# Text(0, 0.5, 'LFP (V)')

# %%
sampling_rate = unit_array.shape[0]/(1587.736098 - 1585.734418)  # Hz
print(sampling_rate)
sigma_ms = 20         # smoothing in milliseconds
sigma_samples = sigma_ms / 1000 * sampling_rate  # convert to samples

firing_rate = gaussian_filter1d(unit_array, sigma=sigma_samples) * sampling_rate
# Out:
# 1249.9500419647006

# %%
plt.figure(figsize=(10, 3))
plt.plot(firing_rate, label='Firing rate (Hz)')
plt.xlabel('Time (ms)')
plt.ylabel('Rate (Hz)')
plt.title('Gaussian-smoothed firing rate')
plt.legend()
plt.show()

plt.figure(figsize=(10, 3))
plt.plot(unit_array, label='unit rate (Hz)')
plt.xlabel('Time (ms)')
plt.ylabel('Rate (Hz)')
plt.title('Gaussian-smoothed firing rate')
plt.legend()
plt.show()

# %% [markdown]
# Applying SHRED on dataset

# %%
#Importing packages

os.environ["CUDA_VISIBLE_DEVICES"]="0"

os.chdir("../") 
os.chdir("/home/amy/SHRED_neuro/shred")
from processdata_shred import load_data as load_data_shred
from processdata_shred import TimeSeriesDataset as TimeSeriesDataset_shred
import models_shred


# Change into the directory
os.chdir("/home/amy/SHRED_neuro/sindy-shred") ## Change to where the repo was cloned

from processdata import load_data
from processdata import TimeSeriesDataset
import sindy
import pysindy as ps
from pysindy.differentiation import FiniteDifference

os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.chdir("/home/amy/SHRED_neuro/sindy-shred")
import sindy_shred

# %%
load_X = np.vstack((lfp_array, firing_rate)).T
print(load_X.shape)

n_t = load_X.shape[0]
n_s = load_X.shape[1]
probe = 'a'
dt = time[1] - time[0]
sr = time.shape[0]/2
print(sr)
print(dt)


latent_dim = 64
poly_order = 1
include_sine = False
library_dim = sindy.library_size(latent_dim, poly_order, include_sine, True)

num_neurons = 1 
lags = 100
test_val_size = 500

train_indices = np.arange(0, n_t - lags - test_val_size)
mask = np.ones(n_t - lags)
mask[train_indices] = 0
valid_test_indices = np.arange(0, n_t - lags)[np.where(mask!=0)[0]]
valid_indices = valid_test_indices[int(test_val_size/2):test_val_size]
test_indices = valid_test_indices[:int(test_val_size/2)]
# Out:
# (2502, 2)
# 1251.0
# 0.0008000013435776054

# %%
k = 0
neuron_locations = [1] #input = firing rate
sc = MinMaxScaler()
sc = sc.fit(load_X[train_indices])
transformed_X = sc.transform(load_X)
### Generate input sequences to a SHRED model
all_data_in = np.zeros((n_t - lags, lags, num_neurons))
for i in range(len(all_data_in)):
    all_data_in[i] = transformed_X[i:i+lags, neuron_locations]

### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
device = 'cuda' if torch.cuda.is_available() else 'cpu'

train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

### -1 to have output be at the same time as final sensor measurements
train_data_out = torch.tensor(transformed_X[train_indices + lags - 1], dtype=torch.float32).to(device)
valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1], dtype=torch.float32).to(device)
test_data_out = torch.tensor(transformed_X[test_indices + lags - 1], dtype=torch.float32).to(device)

train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

shred = sindy_shred.SINDy_SHRED(num_neurons, n_s, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
                                library_dim=library_dim, poly_order=poly_order,
                                include_sine=include_sine, dt=dt, layer_norm=False).to(device)

validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
                                    lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=10.0,
                                    optimizer="AdamW", thres_epoch=100)

test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
print('mse test', mse_test)
train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
print('mse train', mse_train)


file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2.2/train_recons_{probe}_{k}.npy"
np.save(file_path, train_recons)
file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2.2/test_recons_{probe}_{k}.npy"
np.save(file_path, test_recons)
file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2.2/train_gt_{probe}_{k}.npy"
np.save(file_path, train_ground_truth)
file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2.2/test_gt_{probe}_{k}.npy"
np.save(file_path, test_ground_truth)
file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2.2/mse_{probe}_{k}.npy"
np.save(file_path, [mse_train, mse_test])
# Out:
# 1 : tensor(0.0333, device='cuda:0', grad_fn=<AddBackward0>)
# 2 : tensor(0.0391, device='cuda:0', grad_fn=<AddBackward0>)
# 3 : tensor(0.0218, device='cuda:0', grad_fn=<AddBackward0>)
# 4 : tensor(0.0137, device='cuda:0', grad_fn=<AddBackward0>)
# 5 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 6 : tensor(0.0154, device='cuda:0', grad_fn=<AddBackward0>)
# 7 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 8 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 9 : tensor(0.0135, device='cuda:0', grad_fn=<AddBackward0>)
# 10 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 11 : tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
# 12 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 13 : tensor(0.0117, device='cuda:0', grad_fn=<AddBackward0>)
# 14 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 15 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 16 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 17 : tensor(0.0118, device='cuda:0', grad_fn=<AddBackward0>)
# 18 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 19 : tensor(0.0129, device='cuda:0', grad_fn=<AddBackward0>)
# 20 : tensor(0.0125, device='cuda:0', grad_fn=<AddBackward0>)
# 21 : tensor(0.0122, device='cuda:0', grad_fn=<AddBackward0>)
# 22 : tensor(0.0116, device='cuda:0', grad_fn=<AddBackward0>)
# 23 : tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
# 24 : tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
# 25 : tensor(0.0128, device='cuda:0', grad_fn=<AddBackward0>)
# 26 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 27 : tensor(0.0130, device='cuda:0', grad_fn=<AddBackward0>)
# 28 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 29 : tensor(0.0127, device='cuda:0', grad_fn=<AddBackward0>)
# 30 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 31 : tensor(0.0123, device='cuda:0', grad_fn=<AddBackward0>)
# 32 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 33 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 34 : tensor(0.0117, device='cuda:0', grad_fn=<AddBackward0>)
# 35 : tensor(0.0130, device='cuda:0', grad_fn=<AddBackward0>)
# 36 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
#
test_gt = np.load("/home/amy/SHRED_neuro/mice/data_output/exp_2.2/test_gt_a_0.npy")

recons = np.vstack((train_recons, test_recons))
gt = np.vstack((train_gt, test_gt))

# %%
plt.figure(figsize = (6,3))
plt.plot(time[:recons[:,1].shape[0]], gt[:,1], color = 'black', label = 'Ground Truth')
plt.plot(time[:recons[:,1].shape[0]], recons[:,1], color = 'red', linestyle = '--', label = 'Reconstruction')

plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Time (s)', fontsize = 15)
plt.ylabel('Firing Rate (Hz)', fontsize = 15)
plt.legend(fontsize = 13, bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

plt.figure(figsize = (6,3))
plt.plot(time[:recons[:,1].shape[0]], gt[:,0], color = 'black', label = 'Ground Truth')
plt.plot(time[:recons[:,1].shape[0]], recons[:,0], color = 'red', linestyle = '--', label = 'Reconstruction')

plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Time (s)', fontsize = 15)
plt.ylabel('LFP (V)', fontsize = 15)
plt.legend(fontsize = 13, bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %% [markdown]
# **Applying SHRED on Dataset**

# %%
#Importing packages

os.environ["CUDA_VISIBLE_DEVICES"]="0"

os.chdir("../") 
os.chdir("/home/amy/SHRED_neuro/shred")
from processdata_shred import load_data as load_data_shred
from processdata_shred import TimeSeriesDataset as TimeSeriesDataset_shred
import models_shred


# Change into the directory
os.chdir("/home/amy/SHRED_neuro/sindy-shred") ## Change to where the repo was cloned

from processdata import load_data
from processdata import TimeSeriesDataset
import sindy
import pysindy as ps
from pysindy.differentiation import FiniteDifference

os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.chdir("/home/amy/SHRED_neuro/sindy-shred")
import sindy_shred

# %%
load_X = np.vstack((lfp_array, unit_array)).T
print(load_X.shape)

n_t = load_X.shape[0]
n_s = load_X.shape[1]
probe = 'a'
dt = time[1] - time[0]
sr = time.shape[0]/2
print(sr)
print(dt)


latent_dim = 64
poly_order = 1
include_sine = False
library_dim = sindy.library_size(latent_dim, poly_order, include_sine, True)

num_neurons = 1 
lags = 100
test_val_size = 500

train_indices = np.arange(0, n_t - lags - test_val_size)
mask = np.ones(n_t - lags)
mask[train_indices] = 0
valid_test_indices = np.arange(0, n_t - lags)[np.where(mask!=0)[0]]
valid_indices = valid_test_indices[int(test_val_size/2):test_val_size]
test_indices = valid_test_indices[:int(test_val_size/2)]
# Out:
# (2503, 2)
# 1251.5
# 0.0008000025261480914

# %%
# Randomly select the sensors from the CA1 region

for k in range(1):
    neuron_locations = [1]
    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/neuron_loc_{probe}_{k}.npy"
    print(file_path)
    np.save(file_path, neuron_locations)
    sc = MinMaxScaler()
    sc = sc.fit(load_X[train_indices])
    transformed_X = sc.transform(load_X)
    ### Generate input sequences to a SHRED model
    all_data_in = np.zeros((n_t - lags, lags, num_neurons))
    for i in range(len(all_data_in)):
        all_data_in[i] = transformed_X[i:i+lags, neuron_locations]

    ### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
    valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
    test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

    ### -1 to have output be at the same time as final sensor measurements
    train_data_out = torch.tensor(transformed_X[train_indices + lags - 1, 0], dtype=torch.float32).to(device)
    valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1,0], dtype=torch.float32).to(device)
    test_data_out = torch.tensor(transformed_X[test_indices + lags - 1,0], dtype=torch.float32).to(device)

    train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
    valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
    test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

    shred = sindy_shred.SINDy_SHRED(num_neurons, n_s-1, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
                                    library_dim=library_dim, poly_order=poly_order,
                                    include_sine=include_sine, dt=dt, layer_norm=False).to(device)

    validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
                                        lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=10.0,
                                        optimizer="AdamW", thres_epoch=100)

    test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
    test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
    mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
    print('mse test', mse_test)
    train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
    train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
    mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
    print('mse train', mse_train)


    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/train_recons_{probe}_{k}.npy"
    np.save(file_path, train_recons)
    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/test_recons_{probe}_{k}.npy"
    np.save(file_path, test_recons)
    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/train_gt_{probe}_{k}.npy"
    np.save(file_path, train_ground_truth)
    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/test_gt_{probe}_{k}.npy"
    np.save(file_path, test_ground_truth)
    file_path = f"/home/amy/SHRED_neuro/mice/data_output/exp_2/mse_{probe}_{k}.npy"
    np.save(file_path, [mse_train, mse_test])
# Out:
# /home/amy/SHRED_neuro/mice/data_output/exp_2/neuron_loc_a_0.npy
# 1 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 2 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 3 : tensor(0.0083, device='cuda:0', grad_fn=<AddBackward0>)
# 4 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 5 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 6 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 7 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 8 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 9 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 10 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 11 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 12 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 13 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 14 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 15 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 16 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 17 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 18 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 19 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 20 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 21 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 22 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 23 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 24 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 25 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 26 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 27 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 28 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 29 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 30 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 31 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 32 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 33 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 34 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 35 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 36 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 37 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 38 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 39 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 40 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 41 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 42 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 43 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 44 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 45 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 46 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 47 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 48 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 49 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 50 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 51 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 52 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 53 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 54 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 55 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 56 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 57 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 58 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 59 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 60 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 61 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 62 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 63 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 64 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 65 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 66 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 67 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 68 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 69 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 70 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 71 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 72 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 73 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 74 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 75 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 76 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 77 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 78 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 79 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 80 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 81 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 82 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 83 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 84 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 85 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 86 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 87 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 88 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 89 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 90 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 91 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 92 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 93 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 94 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 95 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 96 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 97 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 98 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 99 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 100 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(3.4016, device='cuda:0')
# 101 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 102 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 103 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 104 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 105 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 106 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 107 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 108 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 109 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 110 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 111 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 112 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 113 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 114 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 115 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 116 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 117 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 118 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 119 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 120 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 121 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 122 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 123 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 124 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 125 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 126 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 127 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 128 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 129 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 130 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 131 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 132 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 133 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 134 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 135 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 136 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 137 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 138 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 139 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 140 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 141 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 142 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 143 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 144 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 145 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 146 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 147 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 148 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 149 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 150 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 151 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 152 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 153 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 154 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 155 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 156 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 157 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 158 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 159 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 160 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 161 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 162 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 163 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 164 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 165 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 166 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 167 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 168 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 169 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 170 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 171 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 172 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 173 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 174 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 175 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 176 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 177 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 178 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 179 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 180 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 181 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 182 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 183 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 184 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 185 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 186 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 187 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 188 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 189 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 190 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 191 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 192 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 193 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 194 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 195 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 196 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 197 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 198 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 199 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 200 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(3.3977, device='cuda:0')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 40
#      32 shred = sindy_shred.SINDy_SHRED(num_neurons, n_s-1, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1,
#      33                                 library_dim=library_dim, poly_order=poly_order,
#      34                                 include_sine=include_sine, dt=dt, layer_norm=False).to(device)
#      36 validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=200,
#      37                                     lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=10.0,
#      38                                     optimizer="AdamW", thres_epoch=100)
# ---> 40 test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
#      41 test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
#      42 mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
#
# File ~/SHRED_neuro/neuroenv/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:574, in MinMaxScaler.inverse_transform(self, X)
#     564 xp, _ = get_namespace(X)
#     566 X = check_array(
#     567     X,
#     568     copy=self.copy,
#    (...)
#     571     force_all_finite="allow-nan",
#     572 )
# --> 574 X -= self.min_
#     575 X /= self.scale_
#     576 return X
#
# ValueError: non-broadcastable output operand with shape (250,1) doesn't match the broadcast shape (250,2)

# %%
test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
mse_test = np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth)
print('mse test', mse_test)
train_recons = sc.inverse_transform(shred(train_dataset.X).detach().cpu().numpy())
train_ground_truth = sc.inverse_transform(train_dataset.Y.detach().cpu().numpy())
mse_train = np.linalg.norm(train_recons - train_ground_truth) / np.linalg.norm(train_ground_truth)
print('mse train', mse_train)

# %%
data_recon = np.load("/home/amy/SHRED_neuro/mice/data_output/exp_2/train_recons_a_0.npy")
plt.plot(data_recon[:,0].T)
plt.show()
data_gt = np.load("/home/amy/SHRED_neuro/mice/data_output/exp_2/train_gt_a_0.npy")
plt.plot(data_gt[:,0].T)
